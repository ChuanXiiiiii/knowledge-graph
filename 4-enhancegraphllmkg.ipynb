# %%
import json
with open('data/new/all_list_result-new.json',encoding='utf-8') as f:
    all_list_kg = json.load(f)

# %%
all_list_kg
# Out:
# [["Mr and Mrs Dursley, a seemingly normal couple living on Privet Drive, have a secret fear of their neighbors discovering the Potters, Mrs Dursley's unconventional sister and her family. They are particularly concerned about their son Dudley mixing with the Potters' son. One day, as they go about their mundane routines, unaware of the magical events about to unfold, a tawny owl flies past their window.",
#   0,
#   [['Person', 'Mrs Dursley', 'Sisters', 'Person', 'Mrs Potter', 1],
#    ['Person', 'Mr Dursley', 'Parent of', 'Person', 'Dudley', 1],
#    ['Person', 'Mr Dursley', 'Spouse of', 'Person', 'Mrs Dursley', 1],
#    ['Person', 'Mrs Potter', 'Parent of', 'Person', 'Harry Potter', 1]]],
#  ['Mr. Dursley leaves his house in a rush, noticing strange occurrences like a cat reading a map and people dressed in cloaks. He dismisses these oddities as tricks of the light and new fashion trends, but is increasingly irritated by the unusual sights around him.',
#   1,
#   [['Person', 'Mr Dursley', 'Witnesses', 'MagicalCreature', 'Cat', 1],
#    ['Person', 'Mr Dursley', 'Fear flooded', 'Person', 'Harry Potter', -1]]],
#  ['Mr. Dursley goes about his day, oblivious to strange occurrences involving owls and people in cloaks. However, he becomes alarmed upon overhearing a conversation about the Potters and their son, Harry, leading to a sense of fear and unease.',
#   2,
#   [['Person', 'Mr Dursley', 'Uncertain Relationship', 'Person', 'Harry', 0],
#    ['Person', 'Mr Dursley', 'He looked back', 'Person', 'Harry Potter', 0],
#    ['Person',
#     'Mr Dursley',
#     'Overhear Conversation',
#     'Person',
#     'Harry Potter',
#     1],
#    ['Person', 'Mr Dursley', 'Fear flooded', 'Person', 'Harry Potter', 1]]],
#  ['Mr. Dursley is unsure about his nephew\'s name, worries about strange people in cloaks, and encounters a peculiar old man who mentions "You Know Who" leaving. He is confused by the term "Muggle" and is further unsettled by a cat\'s behavior in his garden.',
#   3,
#   [['Person', 'Mr Dursley', 'Uncertain Relationship', 'Person', 'Harry', 0],
#    ['Person', 'Mr Dursley', 'Spouse of', 'Person', 'Mrs Dursley', -1]]],
#  ['Mr. Dursley tries to act normal after hearing strange news about owls and shooting stars, but eventually asks his wife about her sister, leading to a shocked and angry reaction.',
#   4,
#   [['Person', 'Mrs Dursley', 'Parent of', 'Person', 'Dudley', -1],
#    ['Person', 'Mr Dursley', 'Spouse of', 'Person', 'Mrs Dursley', 1],
#    ['Person', 'Mr Dursley', 'Parent of', 'Person', 'Dudley', -1],
#    ['Person', 'Mrs Dursley', 'Sister of', 'Person', 'Petunia', 0],
#    ['Person', 'Mrs Dursley', 'Sister of', 'Person', 'Lily', 1]]],
#  ['Mr. and Mrs. Dursley discuss strange occurrences in town related to the Potters, particularly their son Harry. Mr. Dursley is worried about the potential connection to the Potters and hopes they will not come near him and his wife due to their negative opinions about them.',
#   5,
#   [['Person', 'Harry Potter', 'Related to', 'Person', 'Petunia', 1],
#    ['Person', 'Mrs Dursley', 'Mentioned name', 'Person', 'Harry Potter', 1],
#    ['Person', 'Petunia', 'FamilyRelation', 'Person', 'Harry Potter', 1],
#    ['Person', 'Mr Dursley', 'Mentioned name', 'Person', 'Harry Potter', 1],
#    ['Person', 'Mr Dursley', 'Negative about', 'Person', 'Harry Potter', 1]]],
#  ['A mysterious man named Albus Dumbledore arrives on Privet Drive, catching the attention of a cat. Despite the unwelcoming atmosphere, Dumbledore seems unfazed as he performs a magical act with a silver cigarette lighter, causing a street lamp to go out.',
#   6,
#   [['Person', 'Cat', 'WitnessesEvent', 'Person', 'Albus Dumbledore', 1],
#    ['Person', 'Dumbledore', 'Meets', 'Person', 'Professor McGonagall', 1],
#    ['Person',
#     'Albus Dumbledore',
#     'Possession',
#     'Object',
#     'Silver cigarette lighter',
#     0],
#    ['Person',
#     'Albus Dumbledore',
#     'Performs magical act with',
#     'Object',
#     'Silver cigarette lighter',
#     1],
#    ['Person', 'Professor McGonagall', 'Possession', 'Person', 'Cat', -1]]],
#  ["Dumbledore uses a device to darken street lamps and reveals Professor McGonagall in cat form. They discuss the celebration of Voldemort's downfall and the Muggles' awareness of magical events. McGonagall is annoyed by the lack of secrecy.",
#   7,
#   [['Person', 'Professor McGonagall', 'Possession', 'Person', 'Cat', 0],
#    ['Person',
#     'Professor McGonagall',
#     'Possession',
#     'MagicalCreature',
#     'Cat',
#     1],
#    ['Person', 'Dumbledore', 'Rivalry', 'Person', 'Voldemort', 1]]],
#  ['Dumbledore and Professor McGonagall discuss the disappearance of Voldemort and the fear of saying his name. McGonagall is concerned about people being careless and revealing the wizarding world to Muggles. Dumbledore offers her a lemon drop and encourages using Voldemort\'s name instead of "You Know Who." McGonagall admires Dumbledore\'s bravery in facing Voldemort.',
#   8,
#   [['Person', 'McGonagall', 'Fear', 'Person', 'Voldemort', 1],
#    ['Person',
#     'Professor McGonagall',
#     'Friendship',
#     'Person',
#     'Dumbledore',
#     1]]],
#  ["Professor McGonagall expresses disbelief at the rumors surrounding Voldemort's disappearance, specifically regarding the fate of Lily and James Potter and their son Harry. She struggles to comprehend how Voldemort, after all his atrocities, could not kill a little boy, leading to his downfall. Dumbledore remains silent, confirming the truth of the rumors.",
#   9,
#   [['Person', 'Voldemort', 'TravelTo', 'Place', "Godric's Hollow", -1],
#    ['Person', 'Voldemort', 'Breaks', 'Miscellaneous', "Voldemort's power", 0],
#    ['Person',
#     'Harry Potter',
#     'Breaks',
#     'Miscellaneous',
#     "Voldemort's power",
#     1],
#    ['Person', 'Voldemort', 'FailedToKill', 'Person', 'Harry Potter', 1],
#    ['Person', 'Voldemort', 'VictimOfSpell', 'Person', 'James Potter', 1],
#    ['Person', 'Harry Potter', 'Interacts with', 'Person', 'McGonagall', 0],
#    ['Person', 'Voldemort', 'VictimOfSpell', 'Person', 'Lily Potter', 1],
#    ['Person', 'Voldemort', 'VictimOfSpell', 'Person', 'Harry Potter', 1]]],
#  ["Dumbledore and Professor McGonagall discuss Harry Potter's survival and his future living with his aunt and uncle. McGonagall is concerned about Harry living with them, but Dumbledore believes it is the best place for him. McGonagall questions Dumbledore's decision, foreseeing Harry's future fame and impact on the wizarding world.",
#   10,
#   [['Person', 'Dumbledore', 'Colleagues', 'Person', 'McGonagall', 1],
#    ['Person', 'Harry Potter', 'Receives', 'Object', 'Letter', 0],
#    ['Person', 'Harry Potter', 'Lives at', 'Place', 'Number four', 0],
#    ['Person',
#     'Harry Potter',
#     'Mentions in future',
#     'Person',
#     'McGonagall',
#     -1]]],
#  ['Dumbledore and McGonagall discuss the importance of keeping Harry Potter away from fame until he is ready. Hagrid arrives on a huge motorcycle to deliver Harry to Dumbledore. McGonagall questions trusting Hagrid, but Dumbledore vouches for him.',
#   11,
#   [['Person', 'Dumbledore', 'Trusts with life', 'Person', 'Hagrid', 1],
#    ['Person', 'McGonagall', 'Doubts capabilities', 'Person', 'Hagrid', 1],
#    ['Person', 'Hagrid', 'Borrows', 'Object', 'Motorcycle', 0],
#    ['Person', 'Hagrid', 'Rides', 'Object', 'Motorcycle', 1],
#    ['Person', 'McGonagall', 'Agrees with', 'Person', 'Dumbledore', -1],
#    ['Person', 'Sirius Black', 'Got out', 'Person', 'Harry', 0]]],
#  ["Sirius Black lent a baby boy, Harry, to Dumbledore and McGonagall. Harry has a lightning-shaped scar on his forehead, and Dumbledore decides not to remove it. Hagrid is emotional about Harry living with the Muggles, and Dumbledore takes Harry to the Dursleys' house.",
#   12,
#   [['Person',
#     'Sirius Black',
#     'Brought to Dumbledore and McGonagall',
#     'Person',
#     'Harry',
#     1],
#    ['Person', 'McGonagall', 'Comforts', 'Person', 'Hagrid', -1],
#    ['Person', 'Hagrid', 'Mentions', 'Person', 'Lily', 0],
#    ['Person', 'Hagrid', 'Concern for well-being', 'Person', 'Harry', 1],
#    ['Person', 'McGonagall', 'Whispers', 'Person', 'Hagrid', 0],
#    ['Person', 'Hagrid', 'Tucked inside', 'Object', 'Letter', 0],
#    ['Person', 'Dumbledore', 'Takes in arms', 'Person', 'Harry', 0],
#    ['Person', 'McGonagall', 'Hisses', 'Person', 'Hagrid', 0],
#    ['Person', 'Hagrid', 'Mentions', 'Person', 'James', 0],
#    ['Person', 'McGonagall', 'Patting', 'Person', 'Dumbledore', 0],
#    ['Person', 'Hagrid', 'Expresses sadness', 'Person', 'Harry', 1],
#    ['Person', 'Hagrid', 'Emotional reaction', 'Person', 'Harry', 1],
#    ['Person', 'Hagrid', 'Kisses', 'Person', 'Harry', 0]]],
#  ["Hagrid, Professor McGonagall, and Dumbledore leave baby Harry on the doorstep of number four Privet Drive. They exchange a few words before departing, with Dumbledore using a magical device to restore the street's lights. The scene ends with Dumbledore wishing Harry good luck and disappearing, leaving the sleeping baby on the doorstep.",
#   13,
#   [['Person', 'Dumbledore', 'Wished good luck', 'Person', 'Harry', 1],
#    ['Person', 'Dumbledore', 'Located at', 'Place', 'Privet Drive', 0],
#    ['Person', 'Harry', 'is left on', 'Place', 'Privet Drive', 1],
#    ['Person', 'Dumbledore', 'Turned on', 'Object', 'Silver Put Outer', 1],
#    ['Person', 'Hagrid', 'Swung onto', 'Object', 'Motorcycle', 1],
#    ['Person', 'Dumbledore', 'Took out', 'Object', 'Silver Put Outer', 1],
#    ['Person', 'Harry', 'Rolled over inside', 'Object', 'Blankets', 0],
#    ['Person', 'Dumbledore', 'Clicked once', 'Object', 'Silver Put Outer', 1],
#    ['Person', 'Harry Potter', 'FamilyRelation', 'Person', 'Mrs Dursley', 1],
#    ['Person', 'Dumbledore', 'Swish of', 'Object', 'Cloak', 0]]],
#  ['The passage describes Harry Potter, a boy who is unaware of his fame and special status as "the boy who lived." It depicts his life with the Dursley family, who treat him poorly while doting on their own son, Dudley. Despite the passage of time, Harry remains hidden and mistreated in the household.',
#   14,
#   [['Person', 'Harry Potter', 'FamilyRelation', 'Person', 'Aunt Petunia', 1],
#    ['Person', 'Harry Potter', 'FamilyRelation', 'Person', 'Dudley Dursley', 1],
#    ['Person', 'Mr Dursley', 'FamilyRelation', 'Person', 'Dudley Dursley', 1],
#    ['Person', 'Harry', 'FamilyRelation', 'Person', 'Dudley', 1]]],
#  ["The text describes Harry waking up on Dudley's birthday, being reminded by his aunt to help with breakfast, and feeling overwhelmed by Dudley's extravagant gifts. Harry is portrayed as small, skinny, and mistreated by his cousin Dudley.",
#   15,
#   [['Person', 'Dudley', 'Possession', 'Object', 'Computer', 0],
#    ['Person', 'Dudley', 'Possession', 'Object', 'Birthday Gifts', 1],
#    ['Person', 'Harry', 'Possession', 'Object', 'Scar', -1],
#    ['Person', 'Harry', 'Nephew-Uncle', 'Person', 'Uncle Vernon', 1],
#    ['Person', 'Dudley', 'Possession', 'Object', 'Bike', 1],
#    ['Person', 'Dudley', 'Possession', 'Object', 'Television', 1],
#    ['Person', 'Harry', 'Possession', 'Object', 'Glasses', 1],
#    ['Person', 'Harry', 'mistreated by', 'Person', 'Dudley', 1]]],
#  ["Harry lived with his Aunt Petunia, Uncle Vernon, and cousin Dudley, who mistreated him. Dudley was spoiled and complained about his birthday presents. Harry tried to avoid Dudley's tantrums by eating quickly. Aunt Petunia tried to appease Dudley by promising more gifts.",
#   16,
#   [['Person', 'Mrs Figg', 'VictimOfSpell', 'Event', 'broken leg', -1],
#    ['Person', 'Dudley', 'Mother-Son', 'Person', 'Aunt Petunia', 1],
#    ['Person', 'Harry', 'Cousins', 'Person', 'Dudley', 1],
#    ['Person', 'Dudley', 'Father-Son', 'Person', 'Uncle Vernon', 1]]],
#  ["Dudley receives many birthday gifts, including a racing bike, video camera, and computer games. Mrs. Figg breaks her leg, leaving Harry without supervision on Dudley's birthday outing. Harry is relieved to avoid spending the day with Mrs. Figg and her cats. Uncle Vernon suggests calling Marge, but Aunt Petunia dismisses the idea due to Marge's dislike for Harry.",
#   17,
#   [['Person', 'Mrs Figg', 'Look after', 'Event', 'Harry', 1],
#    ['Person', 'Harry', 'LeftBehind', 'Person', 'Mrs Figg', 0],
#    ['Person', 'Harry', 'WitnessesEvent', 'Person', 'Mrs Figg', -1],
#    ['Person', 'Uncle Vernon', 'Supports', 'Person', 'Harry', 0],
#    ['Person', 'Harry', 'FamilyRelation', 'Person', 'Dudley', 1],
#    ['Person', 'Marge', 'dislikes', 'Person', 'Harry', 1]]],
#  ['The Dursleys speak about Harry as if he is not there, considering leaving him alone in the car at the zoo. Dudley pretends to cry to manipulate his mother, while his friend Piers, who assists Dudley in bullying others, arrives at their house.',
#   18,
#   [['Person', 'Harry', 'Cuts hair', 'Person', 'Aunt Petunia', 0],
#    ['Person', 'Dudley', 'Rivalry', 'Person', 'Piers Polkiss', 0],
#    ['Person', 'Aunt Petunia', 'FamilyRelation', 'Person', 'Dudley', 1],
#    ['Person', 'Dudley', 'Friendship', 'Person', 'Piers Polkiss', 1]]],
#  ['Harry, accompanied by his unpleasant relatives, is on his way to the zoo for the first time. Despite his assurances, his uncle warns him against causing any trouble due to strange occurrences that happen around Harry. These incidents include his hair growing back overnight and a sweater shrinking when Aunt Petunia tries to make him wear it.',
#   19,
#   [['Person', 'Harry', 'Jump behind', 'Object', 'trash cans', 0],
#    ['Person',
#     'Harry',
#     'Attempts to force sweater',
#     'Person',
#     'Aunt Petunia',
#     0]]],
#  ["Harry got in trouble for being found on the roof of the school kitchens after trying to hide from Dudley's gang. Despite the chaos at home with the Dursleys, Harry was excited to spend the day at the zoo with them.",
#   20,
#   [['Person', 'Harry', 'Dream about', 'Object', 'motorcycle', 0],
#    ['Person', 'Harry', 'FamilyRelation', 'Person', 'Dudley', 1],
#    ['Person', 'Harry', 'Yelled at', 'Person', 'Uncle Vernon', 0]]],
#  ['The Dursleys take Harry, Dudley, and Piers to the zoo. Harry enjoys the outing but is cautious around Dudley and Piers to avoid being hit. Dudley throws a tantrum over his dessert, and they later visit the reptile house where Dudley tries to get a snake to move but fails.',
#   21,
#   [['Person', 'Dudley', 'Possession', 'Object', 'knickerbocker glory', -1],
#    ['Person', 'Dudley', 'Friendship', 'Person', 'Piers', 1],
#    ['Person', 'Uncle Vernon', 'FamilyRelation', 'Person', 'Dudley', 1],
#    ['Person', 'Harry', 'Nearby', 'Person', 'Uncle Vernon', 0],
#    ['Person', 'Harry', 'Nearby', 'Person', 'Dudley', 1],
#    ['Person', 'Harry', 'FamilyRelation', 'Person', 'Uncle Vernon', 1]]],
#  ['Harry interacts with a snake at the zoo, sharing a moment of understanding and communication before being interrupted by Dudley, who pushes Harry to the ground.',
#   22,
#   [['Person', 'Harry', 'Nearby', 'Person', 'Dudley', 1],
#    ['Person', 'Harry', 'Accused by', 'Person', 'Piers', 0],
#    ['Person', 'Harry', 'Interrupted by', 'Person', 'Dudley', 1],
#    ['Person', 'Dudley', 'Assaults', 'Person', 'Harry', 1],
#    ['Person',
#     'Harry',
#     'Communicates with',
#     'MagicalCreature',
#     'Brazilian boa constrictor',
#     1]]],
#  ['Piers and Dudley witness a snake escaping from its tank at the zoo, causing chaos. Harry is blamed for the incident and punished by his abusive relatives, the Dursleys.',
#   23,
#   [['Person', 'Aunt Petunia', 'Guardian of', 'Person', 'Harry', 1],
#    ['Person', 'Uncle Vernon', 'Guardian of', 'Person', 'Harry', 1],
#    ['Person', 'Harry Potter', 'Lives with', 'Person', 'Aunt Petunia', 1],
#    ['Person', 'Dudley', 'Interacts with', 'Person', 'Harry', -1],
#    ['Person', 'Dudley', 'Accomplice of', 'Person', 'Piers', 1]]],
#  ["Harry Potter had lived with the Dursleys for ten miserable years since his parents died in a car crash. He couldn't remember the crash but had strange visions of green light and burning pain. Harry dreamed of being taken away by unknown relatives, but the Dursleys were his only family. Strange encounters with peculiar people made him feel like he was being watched. At school, he was an outcast, especially with Dudley's gang. The escape of a Brazilian boa constrictor led to Harry's longest punishment.",
#   24,
#   [['Person', 'Harry Potter', 'Lives with', 'Person', 'Dudley', 1],
#    ['Person', 'Dudley', 'Friendship', 'Person', 'Piers Polkiss', 1],
#    ['Person',
#     'Harry Potter',
#     'Escapes',
#     'MagicalCreature',
#     'Brazilian boa constrictor',
#     1],
#    ['Person', 'Harry Potter', 'Taken away', 'Person', 'Strangers', 1],
#    ['Person', 'Harry Potter', 'Disliked by', 'Person', "Dudley's gang", 1]]],
#  ["Harry is relieved that school is over but faces bullying from Dudley and his gang during the summer holidays. Despite the mistreatment, Harry finds solace in the upcoming start of secondary school where he won't be with Dudley. Dudley is going to a private school while Harry is going to a public school, causing Dudley to mock Harry. Aunt Petunia takes Dudley to buy his school uniform, leaving Harry with Mrs Figg who is more lenient due to a broken leg.",
#   25,
#   [['Person', 'Dudley', 'Wears', 'Object', 'maroon tailcoats', 0],
#    ['Person', 'Dudley', 'TravelTo', 'Place', 'London', 1],
#    ['Person', 'Harry', 'FamilyRelation', 'Person', 'Aunt Petunia', 1],
#    ['Person', 'Dudley', 'Friendship', 'Person', 'Piers Polkiss', 1],
#    ['Person', 'Harry', 'FamilyRelation', 'Person', 'Uncle Vernon', 1],
#    ['Person', 'Harry', 'LocatedIn', 'Place', "Mrs Figg's", 1]]],
#  ["Dudley proudly shows off his new school uniform, while Harry is given a shabby, ill-fitting uniform made from Dudley's old clothes. The family is excited about Dudley's uniform, but Harry is embarrassed by his.",
#   26,
#   [['Person', 'Harry', 'Looks in', 'Object', 'bowl', 0],
#    ['Person', 'Dudley', 'Related to', 'Person', 'Aunt Petunia', 1],
#    ['Person', 'Harry Potter', 'Opens', 'Object', 'Envelope', -1],
#    ['Person', 'Harry', 'Related to', 'Person', 'Uncle Vernon', 1],
#    ['Person', 'Harry', 'Asks', 'Person', 'Aunt Petunia', -1],
#    ['Person', 'Harry', 'Sits down at', 'Object', 'table', -1],
#    ['Person', 'Dudley', 'Related to', 'Person', 'Uncle Vernon', 1],
#    ['Person', 'Dudley', 'Carries', 'Object', 'knobbly sticks', -1],
#    ['Person', 'Harry', 'Owns', 'Object', 'new school uniform', 1],
#    ['Person',
#     'Harry',
#     'feel embarrassed about',
#     'Object',
#     'his old school uniform',
#     1],
#    ['Person', 'Dudley', 'shows off', 'Object', 'his new school uniform', 1],
#    ['Person',
#     'Dursleys',
#     'feel excited about',
#     'Object',
#     'new school uniform',
#     1],
#    ['Person', 'Harry', 'Sees', 'Object', 'large metal tub', 0],
#    ['Person', 'Harry', 'Sees', 'Object', 'dirty rags', 1],
#    ['Person', 'Harry', 'Tries not to think about', 'Object', 'table', 0],
#    ['Person', 'Dudley', 'Wears', 'Object', 'flat straw hats', 0],
#    ['Person', 'Dudley', 'Wears', 'Object', 'orange knickerbockers', 0],
#    ['Person', 'Harry', 'Related to', 'Person', 'Dudley', 1],
#    ['Person', 'Harry', 'Sees', 'Object', 'gray water', 0]]],
#  ["Harry is asked to get the mail by his uncle, but both Dudley and Harry try to make each other get it. Harry eventually retrieves the mail and finds a letter addressed to him, which surprises him as he has never received a letter before. The letter is thick, heavy, and made of yellowish parchment with an emerald green ink address and a purple wax seal with a coat of arms. Harry's uncle rushes him to open the letter, while also commenting on the other mail received.",
#   27,
#   [['Object', 'Envelope', 'Bears', 'Object', 'purple wax Seal', 1],
#    ['Person', 'Uncle Vernon', 'Rips open', 'Object', 'Bill', 0],
#    ['Person', 'Harry', 'Rips open', 'Object', 'Envelope', 1],
#    ['Person', 'Dudley', 'Calls', 'Person', 'Uncle Vernon', 1],
#    ['Person', 'Uncle Vernon', 'Informs', 'Person', 'Aunt Petunia', 1],
#    ['Person', 'Harry', 'Siblings', 'Person', 'Dudley', 1]]],
#  ["Harry's family reacts with shock and fear upon receiving a mysterious letter addressed to him, leading to a tense confrontation between Harry, his uncle, and his cousin.",
#   28,
#   [['Person', 'Harry', 'Nephew of', 'Person', 'Aunt Petunia', 1],
#    ['Person', 'Uncle Vernon', 'Spouse', 'Person', 'Aunt Petunia', 1],
#    ['Person', 'Uncle Vernon', 'Visited', 'Person', 'Harry', 1],
#    ['Person',
#     'Dursleys',
#     'feel scared because a letter addressed to Harry',
#     'Person',
#     'Harry',
#     1],
#    ['Person', 'Harry', 'Nephew of', 'Person', 'Uncle Vernon', 1]]],
#  ["Aunt Petunia and Uncle Vernon are concerned about a mysterious letter addressed to Harry. Uncle Vernon decides to ignore it and forbids Harry from asking questions, eventually suggesting that Harry move into Dudley's second bedroom.",
#   29,
#   [['Person', 'Uncle Vernon', 'Burned letter', 'Person', 'Harry', -1],
#    ['Person', 'Dudley', 'Uses', 'Object', 'Smelting stick', 0],
#    ['Person', 'Uncle Vernon', 'Forced relocation', 'Person', 'Harry', 1]]],
#  ["Harry moves from the cupboard to Dudley's room, which is filled with broken items. Dudley throws a tantrum as he is forced to share his room with Harry. The Dursleys are tense, and Dudley's behavior worsens. Uncle Vernon tries to be nice to Harry, but tension remains high in the household.",
#   30,
#   [['Person', 'Dudley', 'Hits', 'Person', 'father', 1],
#    ['Person', 'Dudley', 'Throws through', 'Object', 'greenhouse roof', 0],
#    ['Person', 'Uncle Vernon', 'Tries to be nice to', 'Person', 'Harry', 1],
#    ['Person', 'Dudley', 'Kicks', 'Person', 'mother', 0],
#    ['Person', 'Dudley', 'Throws', 'Object', 'tortoise', 0],
#    ['Person', 'Dudley', 'Vomits on', 'Person', 'mother', 0],
#    ['Person', 'Uncle Vernon', 'Tries to get', 'Object', 'Letter', -1],
#    ['Person', 'Dudley', 'Wants back', 'Object', 'room', 1],
#    ['Person', 'Dudley', 'Screams at', 'Person', 'mother', 0]]],
#  ['Harry tries to intercept a letter addressed to him, but his uncle catches him and scolds him for trying to sneak out. Harry plans to intercept the next letter by waking up early, but his uncle catches him again and scolds him.',
#   31,
#   [['Person', 'Harry', 'Receives', 'Object', 'letters', -1],
#    ['Person', 'Harry Potter', 'Startled by', 'Person', 'Uncle Vernon', 0],
#    ['Person', 'Harry Potter', 'Steps on', 'Person', 'Uncle Vernon', 0],
#    ['Person', 'Harry Potter', 'Sets', 'Object', 'Alarm Clock', -1],
#    ['Person', 'Harry Potter', 'Turns off', 'Object', 'Alarm Clock', -1]]],
#  ['Harry receives multiple letters addressed in green ink, but Uncle Vernon tears them up and tries to prevent more from coming by nailing up the mail slot. Despite his efforts, letters keep arriving in various ways, causing chaos in the house. Uncle Vernon boards up the doors to stop the letters, but they still find their way in. By Sunday, Uncle Vernon is exhausted but relieved.',
#   32,
#   [['Person', 'Uncle Vernon', 'Destroys', 'Object', 'letters', 1],
#    ['Person', 'Aunt Petunia', 'Shreds', 'Object', 'letters', 0],
#    ['Person', 'Uncle Vernon', 'Boards up', 'Place', 'house', 0],
#    ['Person', 'Uncle Vernon', 'Makes telephone calls', 'Object', 'letters', 0],
#    ['Person', 'Dudley', 'Ate breakfast', 'Person', 'Harry', 0],
#    ['Person', 'Aunt Petunia', 'Destroys', 'Object', 'letters', 0],
#    ['Person', 'Uncle Vernon', 'Destroys', 'Object', 'letters', 1],
#    ['Person', 'Uncle Vernon', 'Boards up', 'Object', 'cracks', 0],
#    ['Person',
#     'Uncle Vernon',
#     'Boards up',
#     'Object',
#     'front and back doors',
#     1],
#    ['Person', 'Uncle Vernon', 'Communicates', 'Person', 'Aunt Petunia', 0]]],
#  ['Dudley and Harry share a room with twin beds in a hotel. They have a strange encounter with the hotel owner regarding a letter addressed to Mr. H. Potter. Uncle Vernon takes the letter and drives the family around aimlessly. Dudley becomes upset as they are locked in the car in the rain. Dudley mentions wanting to watch a TV show, which triggers a memory in Harry.',
#   34,
#   [['Person', 'Dudley', 'Mentioned Monday', 'Person', 'Aunt Petunia', 0],
#    ['Person', 'Uncle Vernon', 'Parked at coast', 'Person', 'Dudley', 0],
#    ['Person',
#     'Dudley',
#     'Told about television show',
#     'Person',
#     'Aunt Petunia',
#     0],
#    ['Person', 'Uncle Vernon', 'Drove to parking garage', 'Person', 'Harry', 0],
#    ['Person', 'Uncle Vernon', 'Drove into forest', 'Person', 'Harry', 0],
#    ['Person',
#     'Dudley',
#     'Asked about Uncle Vernon',
#     'Person',
#     'Aunt Petunia',
#     0],
#    ['Person', 'Uncle Vernon', 'Drove to plowed field', 'Person', 'Harry', 0],
#    ['Person',
#     'Uncle Vernon',
#     'Suggested going home',
#     'Person',
#     'Aunt Petunia',
#     0],
#    ['Person', 'Uncle Vernon', 'Knocked hand', 'Person', 'Harry', 0],
#    ['Person',
#     'Uncle Vernon',
#     'Drove to suspension bridge',
#     'Person',
#     'Harry',
#     0],
#    ['Person', 'Harry', 'FamilyRelation', 'Person', 'Uncle Vernon', 1],
#    ['Person',
#     'Uncle Vernon',
#     'Ignored suggestion',
#     'Person',
#     'Aunt Petunia',
#     0]]],
#  ["A giant man knocks down the door of Harry's shack, revealing himself as the Keeper of the Keys. He is friendly towards Harry, recalling the last time he saw him as a baby. Dudley and his family are terrified by the giant's appearance.",
#   37,
#   [['Person', 'Harry', 'Friendship', 'Person', 'Hagrid', 1],
#    ['Person', 'Uncle Vernon', 'FamilyRelation', 'Person', 'Dudley', -1],
#    ['Person', 'Harry', 'WitnessesEvent', 'Person', 'Hagrid', 1],
#    ['Person', 'Harry', 'Looks like', 'Person', 'Dad', -1]]],
#  ['Uncle Vernon is surprised by the arrival of a giant named Hagrid who brings Harry a birthday cake. Hagrid reveals he works at Hogwarts and magically starts a fire in the fireplace.',
#   38,
#   [['Person', 'Giant', 'Shakes hands', 'Person', 'Harry', 0],
#    ['Person', 'Giant', 'Requests tea', 'Person', 'Harry', 0],
#    ['Person', 'Giant', 'Works at', 'Place', 'Hogwarts', 1],
#    ['Person', 'Giant', 'Insults Dursley', 'Person', 'Uncle Vernon', 0],
#    ['Person', 'Harry', 'Has eyes', 'Person', 'Mom', -1],
#    ['Person', 'Giant', 'Introduces as Hagrid', 'Person', 'Harry', 1],
#    ['Person', 'Giant', 'Wishes birthday', 'Person', 'Harry', 1],
#    ['Person', 'Uncle Vernon', 'Breaks gun', 'Person', 'Harry', 0],
#    ['Person', 'Uncle Vernon', 'Demands to leave', 'Person', 'Harry', 0],
#    ['Person', 'Hagrid', 'Keeper of Keys', 'Place', 'Hogwarts', -1]]],
#  ['A giant named Hagrid visits Harry and his family, revealing that Harry is a wizard and inviting him to attend Hogwarts School of Witchcraft and Wizardry. Harry is surprised and curious about this new world he is introduced to.',
#   39,
#   [['Person', 'Hagrid', 'Interacts with', 'Person', 'Vernon', 0],
#    ['Person', 'Harry', 'Thought this', 'Person', 'Hagrid', 1],
#    ['Person', 'Hagrid', 'Interacts with', 'Person', 'Dudley', 0],
#    ['Person', 'Harry', 'Knows about', 'Place', 'Hogwarts', 1],
#    ['Person', 'Harry', 'Meets', 'Person', 'Hagrid', 1],
#    ['Person', 'Harry', 'Related to', 'Person', 'Dudley', 1]]],
#  ['Hagrid confronts the Dursleys about Harry not knowing anything about the wizarding world, revealing that Harry is famous and has magical parents. Uncle Vernon tries to stop Hagrid from telling Harry more, but Hagrid is furious that Harry has been kept in the dark for so long.',
#   40,
#   [['Person', 'Uncle Vernon', 'Whispered something', 'Person', 'Hagrid', 0],
#    ['Person', 'Hagrid', 'Boomed', 'Person', 'Dursley', -1],
#    ['Person', 'Harry', 'Received', 'Object', 'letter', -1],
#    ['Person', 'Dumbledore', 'Left letter for', 'Person', 'Dursley', 0],
#    ['Person', 'Hagrid', 'Gave furious look', 'Person', 'Dursley', 1],
#    ['Person', 'Hagrid', 'Fixed with stare', 'Person', 'Harry', 1],
#    ['Person', 'Uncle Vernon', 'Commanded', 'Person', 'Hagrid', 0]]],
#  ['Harry is told by Hagrid that he is a wizard and has been accepted to Hogwarts School of Witchcraft and Wizardry. He receives a letter with instructions for the upcoming school term, leading to questions swirling in his mind.',
#   41,
#   [['Person', 'Harry', 'Reads', 'Document', 'letter', 1],
#    ['Person', 'Harry', 'Sent by', 'Person', 'Minerva McGonagall', -1],
#    ['Person', 'Harry', 'Accepted at', 'Place', 'Hogwarts', 1],
#    ['Person', 'Hagrid', 'Taking him', 'Person', 'Harry', -1]]],
#  ["Hagrid writes a note to Dumbledore about taking Harry to buy his school supplies, while Harry's aunt and uncle express their disbelief and anger at Harry being a wizard.",
#   42,
#   [['Person', 'Hagrid', 'Took him', 'Person', 'Harry', 1],
#    ['Person', 'Lily Potter', 'Parent of', 'Person', 'Harry Potter', -1],
#    ['Person', 'Harry', 'Shrieked', 'Person', 'Aunt Petunia', 0],
#    ['Person', 'Hagrid', 'Gave it', 'MagicalCreature', 'owl', 0],
#    ['Person', 'Harry', 'Said', 'Person', 'Uncle Vernon', 1],
#    ['Person', 'Hagrid', 'Moved into', 'Person', 'Uncle Vernon', 0],
#    ['Person', 'Hagrid', 'Said', 'Person', 'Uncle Vernon', 1],
#    ['Person', 'Hagrid', 'Grunted', 'Person', 'Uncle Vernon', 0],
#    ['Person', 'Hagrid', 'Dear Professor', 'Person', 'Dumbledore', 1]]],
#  ['A girl named Lily received a letter and went to a magical school, Hogwarts, where she was seen as a witch by her family. She later married James Potter and had a son, Harry. Harry learns from Hagrid that his parents did not die in a car crash as he was told, but were killed in a scandalous event. Hagrid is worried about Harry not knowing his own story and decides to reveal some information about his mysterious past.',
#   43,
#   [['Person', 'James Potter', 'Parent of', 'Person', 'Harry Potter', 1],
#    ['Person', 'Dumbledore', 'Feared by', 'Person', 'Voldemort', -1],
#    ['Person', 'Lily Potter', 'Killed by', 'Person', 'Harry Potter', 0],
#    ['Person', 'Harry Potter', 'Informed by', 'Person', 'Hagrid', 1],
#    ['Person', 'Lily Potter', 'Sister of', 'Person', 'Petunia Dursley', 1],
#    ['Person', 'Harry Potter', 'Informed by', 'Person', 'Dumbledore', -1]]],
#  ["Hagrid tells Harry about a dark wizard named Voldemort who caused fear and chaos in the wizarding world, seeking followers and power. Harry's parents were skilled wizards who opposed Voldemort, and he never tried to recruit them due to their loyalty to Dumbledore.",
#   44,
#   [['Person', 'Harry', 'UnderCurse', 'Person', 'Voldemort', 0],
#    ['Person', 'Harry', 'RevengeAgainst', 'Person', 'Voldemort', -1],
#    ['Person', 'Harry', 'VictimOfSpell', 'Person', 'Voldemort', 1],
#    ['Person', 'Harry', 'WitnessesEvent', 'Person', 'Voldemort', 0],
#    ['Person', 'Harry', 'Tried to kill', 'Person', 'You Know Who', 0],
#    ['Person', 'Harry', 'Mentor of', 'Person', 'Dumbledore', 0],
#    ['Person', 'Harry', 'Enemy of', 'Person', 'Voldemort', 1],
#    ['Person', 'Dumbledore', 'Mentor of', 'Person', 'Harry', 1]]],
#  ["Hagrid tells Harry about how he survived an attack by the dark wizard Voldemort as a baby, resulting in a lightning-shaped scar on his forehead. Voldemort killed Harry's parents but failed to kill Harry, making him famous in the wizarding world. Harry recalls the attack and a cold, cruel laugh for the first time. Hagrid reveals he was the one who brought Harry to live with the Dursleys on Dumbledore's orders. Uncle Vernon dismisses the story as nonsense.",
#   45,
#   [['Person', 'Hagrid', 'Interacted with', 'Person', 'Uncle Vernon', 0],
#    ['Person', 'Harry', 'Interacted with', 'Person', 'Uncle Vernon', -1],
#    ['Person', 'Harry', 'Rescued by', 'Person', 'Dumbledore', -1],
#    ['Person', 'Harry', "Couldn't do it", 'Person', 'You Know Who', 0],
#    ['Person', 'Harry', 'Asks about Voldemort', 'Person', 'Voldemort', 0],
#    ['Person', 'Harry', 'Killed parents', 'Person', 'You Know Who', 1],
#    ['Person', 'Hagrid', 'Told story to', 'Person', 'Harry', 1],
#    ['Person', 'Harry', 'Listened to story', 'Person', 'Hagrid', 1]]],
#  ["Hagrid confronts Uncle Vernon about his disrespectful comments towards Harry's parents and warns him with an umbrella. Hagrid reveals that Voldemort disappeared after trying to kill Harry and speculates on his fate, suggesting that Harry played a role in his downfall.",
#   46,
#   [['Person', 'Voldemort', 'Defeated by Harry', 'Person', 'Harry', -1],
#    ['Person', 'Harry Potter', 'Rival of', 'Person', 'Dudley', -1],
#    ['Person', 'Voldemort', 'Tried to kill', 'Person', 'Harry', 1]]],
#  ["Hagrid informs Harry that he is a wizard, which Harry finds hard to believe due to his mistreatment by his family. Hagrid points out instances where Harry unknowingly used magic, convincing him of his wizarding abilities. Despite Uncle Vernon's objections, Harry is destined to attend Hogwarts and become famous.",
#   47,
#   [['Person', 'Harry Potter', 'Rival of', 'Person', 'Dudley', 1],
#    ['Person', 'Harry Potter', 'Rival of', 'Person', 'Uncle Vernon', -1],
#    ['Person', 'Harry Potter', 'Goes to', 'Place', 'Hogwarts', 1],
#    ['Person', 'Harry Potter', 'Rival of', 'Person', 'Aunt Petunia', -1]]],
#  ["Hagrid defends Harry's right to attend Hogwarts, a school of witchcraft and wizardry, against Uncle Vernon's objections. Hagrid attempts to turn Dudley into a pig but fails, causing chaos.",
#   48,
#   [['Person', 'Hagrid', 'Victim of spell', 'Person', 'Dudley Dursley', 0],
#    ['Person', 'Harry Potter', 'Aunt of', 'Person', 'Petunia Dursley', 0],
#    ['Person', 'Harry Potter', 'Uncle of', 'Person', 'Vernon Dursley', 0],
#    ['Person', 'Harry Potter', 'Mother of', 'Person', 'Lily Potter', 0],
#    ['Person', 'Harry Potter', 'Father of', 'Person', 'James Potter', 0],
#    ['Person', 'Hagrid', 'Casts spell', 'Person', 'Dudley Dursley', 1],
#    ['Person', 'Harry Potter', 'Mentor of', 'Person', 'Albus Dumbledore', -1],
#    ['Person', 'Hagrid', 'Possession', 'Object', 'wand', 1],
#    ['Person', 'Hagrid', 'Transformed into', 'Person', 'Dudley Dursley', 0]]],
#  ['Hagrid reveals to Harry that he was expelled from Hogwarts in his third year, but Dumbledore allowed him to stay on as the gamekeeper. The next morning, Harry wakes up from a dream about Hagrid and realizes he is not in his cupboard at home.',
#   49,
#   [['Person', 'Harry', 'Possession', 'Object', 'wizard coins', 0],
#    ['Person', 'Hagrid', 'LocatedIn', 'Place', 'Hogwarts', 1],
#    ['Person', 'Hagrid', 'Possession', 'Object', 'coat', 1],
#    ['Person', 'Harry', 'Possession', 'Object', 'coat', 0]]],
#  ["Harry wakes up in a sunny hut with Hagrid asleep on the sofa. An owl delivers a newspaper and demands payment, which Harry gives from Hagrid's coat. Hagrid plans to take Harry shopping for school supplies in London. Harry realizes something troubling as he examines wizard coins.",
#   50,
#   [['Person', 'Harry', 'Possession', 'Object', 'wizard coins', 1],
#    ['Person', 'Harry', 'FamilyRelation', 'Person', 'Uncle Vernon', -1]]],
#  ['Harry is worried about not having money to learn magic, but Hagrid reassures him that his parents may have left him something. Hagrid takes Harry to Gringotts, a wizard bank run by goblins, to access his inheritance. Hagrid emphasizes the importance of not messing with goblins and the security of Gringotts. Hagrid mentions that he is on Hogwarts business for Dumbledore and that he is trusted to handle important tasks. They then leave for Gringotts, with Hagrid mentioning that they will not use magic to travel.',
#   51,
#   [['Person', 'Harry', 'ParticipatesInEvent', 'Place', 'Gringotts', 1],
#    ['Person', 'Hagrid', 'LeadsEvent', 'Person', 'Harry', 0],
#    ['Person', 'Hagrid', 'Possession', 'Object', 'pink umbrella', -1],
#    ['Person', 'Hagrid', 'LocatedIn', 'Place', 'Hogwarts', 0],
#    ['Person', 'Harry', 'ParticipatesInEvent', 'Place', 'Hogwarts', 0],
#    ['Person', 'Harry', 'Friendship', 'Person', 'Hagrid', 1],
#    ['Person', 'Harry', 'Friendship', 'Person', 'Dumbledore', -1],
#    ['Person', 'Hagrid', 'LocatedIn', 'Place', 'Gringotts', 1],
#    ['Person', 'Hagrid', 'ParticipatesInEvent', 'Place', 'Gringotts', 1],
#    ['Person', 'Harry', 'LocatedIn', 'Place', 'Gringotts', 1]]],
#  ["Hagrid asks Harry not to mention speeding up the boat at Hogwarts. Hagrid explains the dangers of robbing Gringotts due to spells, enchantments, and dragons guarding the vaults. He mentions the Ministry of Magic's role in hiding magic from Muggles to avoid everyone seeking magical solutions to their problems.",
#   52,
#   [['Person', 'Cornelius Fudge', 'Rivalry', 'Person', 'Dumbledore', 0],
#    ['Person', 'Hagrid', 'Friendship', 'Person', 'Dumbledore', -1],
#    ['Person', 'Dumbledore', 'Rivalry', 'Person', 'Cornelius Fudge', 0],
#    ['Person', 'Hagrid', 'Mentions Hogwarts School', 'Place', 'Hogwarts', 1],
#    ['Person',
#     'Cornelius Fudge',
#     'Seeks advice from',
#     'Person',
#     'Dumbledore',
#     0],
#    ['Person', 'Hagrid', 'ReadsDocument', 'Document', 'Daily Prophet', 0],
#    ['Person',
#     'Dumbledore',
#     'Leadership',
#     'Organisation',
#     'Ministry of Magic',
#     -1],
#    ['Person', 'Hagrid', 'LocatedIn', 'Place', 'Gringotts', 1],
#    ['Person', 'Hagrid', 'Membership', 'Organisation', 'Ministry of Magic', 0],
#    ['Person', 'Harry', 'Curious about', 'Person', 'Hagrid', -1]]],
#  ['Hagrid and Harry arrive at a town and head to the station to catch a train to London. Hagrid, a giant, attracts attention with his fascination with Muggle objects. They discuss dragons and Hogwarts, with Hagrid knitting on the train. Harry reads a list of required items for Hogwarts School of Witchcraft and Wizardry.',
#   53,
#   [['Person', 'Harry', 'Has letter', 'Document', 'parchment envelope', -1],
#    ['Object', 'wand', 'Possession', 'Person', 'Harry', -1]]],
#  ['The text describes a list of required items for students attending a magical school, including clothing, course books, and other equipment. It also depicts a scene where a character named Harry, accompanied by Hagrid, navigates through London in search of magical supplies, expressing wonder at the existence of hidden wizarding shops among ordinary ones.',
#   54,
#   [['Person', 'Harry', 'TravelTo', 'Place', 'London', 1],
#    ['Person', 'Hagrid', 'TravelTo', 'Place', 'London', 1],
#    ['Person', 'Harry Potter', 'Trusts', 'Person', 'Hagrid', -1]]],
#  ['Harry and Hagrid arrive at the Leaky Cauldron, a hidden pub in the wizarding world. Despite its shabby appearance, the patrons recognize Harry as a famous figure, causing a stir of excitement and warm welcome.',
#   55,
#   [['Person', 'Hagrid', 'Familiar with', 'Place', 'Leaky Cauldron', 1],
#    ['Person', 'Harry Potter', 'Recognizes', 'Person', 'Bartender', 0],
#    ['Person',
#     'Harry Potter',
#     'Met at last',
#     'Person',
#     'Doris Crockford',
#     -1]]],
#  ['Harry is overwhelmed by the attention and excitement of meeting various people at the Leaky Cauldron, including Doris Crockford, Dedalus Diggle, and Professor Quirrell, who will be teaching Defense Against the Dark Arts at Hogwarts. Professor Quirrell appears nervous and stammers while expressing his pleasure at meeting Harry.',
#   56,
#   [['Person', 'Harry Potter', 'Met before', 'Person', 'Dedalus Diggle', 0],
#    ['Person',
#     'Professor Quirrell',
#     'Picks up',
#     'Object',
#     'Book on vampires',
#     -1],
#    ['Person', 'Hagrid', 'LeadsEvent', 'Person', 'Harry', 0],
#    ['Person',
#     'Harry Potter',
#     'Future teacher',
#     'Person',
#     'Professor Quirrell',
#     1]]],
#  ["Hagrid takes Harry to Diagon Alley, a hidden magical street, where they encounter Professor Quirrell and Hagrid reveals some of Quirrell's past encounters with vampires and hags.",
#   57,
#   [['Person', 'Professor Quirrell', 'WitnessesEvent', 'Person', 'Harry', 0],
#    ['Person', 'Harry', 'LocatedIn', 'Object', 'Cauldrons', 0],
#    ['Person', 'Professor Quirrell', 'TravelTo', 'Place', 'Black Forest', 0],
#    ['Object',
#     'Cauldrons',
#     'Described as',
#     'Object',
#     'Self Stirring Collapsible',
#     1],
#    ['Person', 'Professor Quirrell', 'Possession', 'Object', 'Umbrella', -1],
#    ['Person', 'Doris Crockford', 'Friendship', 'Person', 'Harry', 1],
#    ['Person', 'Professor Quirrell', 'Meets', 'MagicalCreature', 'Hags', 1],
#    ['Person', 'Harry', 'TravelTo', 'Place', 'Diagon Alley', 1],
#    ['Person',
#     'Professor Quirrell',
#     'Meets',
#     'MagicalCreature',
#     'Vampires',
#     1]]],
#  ['Harry and Hagrid explore a magical shopping street filled with various shops selling wizarding supplies. They encounter cauldrons, broomsticks, potion ingredients, and a goblin guarding Gringotts bank.',
#   58,
#   [['Person', 'Goblin', 'Very long', 'Object', 'Feet', 0],
#    ['Person', 'Harry', 'Wished for', 'Object', 'Eyes', 0],
#    ['Person', 'Goblin', 'Very long', 'Object', 'Fingers', 0],
#    ['Person', 'Goblin', 'Wearing', 'Object', 'Uniform', -1],
#    ['Person', 'Harry', 'Shops selling', 'Object', 'Robes', -1],
#    ['Person', 'Harry', 'Trying to look at', 'Place', 'Shops', -1],
#    ['Person', 'Goblin', 'Uniform of', 'Object', 'Scarlet and gold', -1],
#    ['Person',
#     'Hagrid',
#     'Has',
#     'Document',
#     'letter from Professor Dumbledore',
#     1],
#    ['Person', 'Hagrid', 'Said about', 'Object', 'Cauldrons', -1],
#    ['Person', 'Harry', 'Shops selling', 'Object', 'Telescopes', -1],
#    ['Person', 'Harry', 'Needs to get', 'Object', 'Money', 1],
#    ['Person', 'Harry', 'Stacked with', 'Object', 'Potion bottles', 1],
#    ['Person', 'Harry', 'Piles of', 'Object', 'Spell books', 1],
#    ['Person', 'Several boys', 'Looking at', 'Object', 'Broomsticks', 1],
#    ['Person', 'Harry', 'Walked up', 'Place', 'Street', 1],
#    ['Person', 'Harry', 'Strange silver', 'Object', 'Instruments', -1],
#    ['Person', 'Plump woman', 'Selling at', 'Object', 'Dragon liver', -1],
#    ['Person', 'Goblin', 'Walked up', 'Place', 'White stone steps', 1],
#    ['Person', 'Harry', 'Of the moon', 'Object', 'Globes', -1],
#    ['Person', 'Hagrid', 'Said about', 'Place', 'Gringotts', 1],
#    ['Person', 'Goblin', 'Beside', 'Object', 'Doors', 1],
#    ['Person', 'Goblin', 'Doors of', 'Object', 'Burnished bronze', 1]]],
#  ["Hagrid and Harry are warned about the consequences of greed before entering a bank guarded by goblins. Hagrid presents a key and a letter from Professor Dumbledore to access Harry's safe in vault seven hundred and thirteen. The goblin agrees to take them to both vaults.",
#   59,
#   [['Person', 'Hagrid', 'Delivers letter to', 'Person', 'Harry Potter', 0],
#    ['Person', 'Hagrid', 'Refers to', 'Person', 'Professor Dumbledore', 1],
#    ['Person', 'Hagrid', 'Accompanying', 'Person', 'Harry', 1],
#    ['Person', 'goblin', 'Weighing', 'Object', 'pile of rubies', 0],
#    ['Person', 'Hagrid', 'Possesses', 'Object', 'moldy dog biscuits', 0],
#    ['Person', 'Hagrid', 'Takes money outta', 'Person', 'Harry Potter', 0]]],
#  ["Harry, Hagrid, and Griphook journey through a narrow stone passageway on a cart towards vault seven hundred and thirteen. Hagrid refuses to reveal the secret inside the vault, claiming it's Hogwarts business. The trio hurtles through twisting passages, passing by an underground lake with stalactites and stalagmites. Harry asks Hagrid about the difference between stalactites and stalagmites, to which Hagrid humorously responds.",
#   60,
#   [['Person', 'Hagrid', 'Helps carry', 'Object', 'bag', 0],
#    ['Person', 'Harry', 'AskingQuestion', 'Person', 'Hagrid', 1]]],
#  ['Harry, Hagrid, and Griphook visit vault seven hundred and thirteen at Gringotts, where Harry discovers a small fortune in gold coins, silver, and bronze Knuts that belong to him. Hagrid helps Harry gather some of the money, explaining the wizarding currency system. Griphook opens the vault with ease, revealing the dangers of unauthorized entry.',
#   61,
#   [['Person', 'Harry', 'Learns about', 'Object', 'Galleons', 1],
#    ['Person', 'Hagrid', 'Explains about', 'Object', 'gold coins', 1],
#    ['Person', 'Hagrid', 'Explains about', 'Object', 'Knuts', 1],
#    ['Person',
#     'Harry',
#     'Asks about',
#     'Object',
#     'Vault seven hundred and thirteen',
#     0],
#    ['Person', 'Harry', 'Learns about', 'Object', 'Sickles', 1],
#    ['Person', 'Harry', 'Noticed', 'Object', 'grubby little package', 0],
#    ['Person', 'Harry', 'Sees', 'Object', 'gold coins', 1],
#    ['Person', 'Hagrid', 'Explains about', 'Object', 'Sickles', 1],
#    ['Person', 'Hagrid', 'Explains about', 'Object', 'Galleons', 1],
#    ['Person', 'Griphook', 'Makes disappear', 'Object', 'door', 0],
#    ['Person', 'Harry', 'Learns about', 'Object', 'Knuts', 1],
#    ['Person', 'Griphook', 'Unlocks', 'Object', 'door', 1],
#    ['Person',
#     'Hagrid',
#     'Requests access to',
#     'Object',
#     'Vault seven hundred and thirteen',
#     1]]],
#  ["Griphook and Hagrid take Harry to a top security vault at Gringotts where they retrieve a mysterious package. Hagrid hides it in his coat, and they return to the surface. Harry is excited to have a bag full of money and goes to buy his Hogwarts uniform at Madam Malkin's shop, where he meets another boy also getting fitted for Hogwarts robes.",
#   62,
#   [['Person',
#     'Harry',
#     'Entered',
#     'Place',
#     "Madam Malkin's Robes for All Occasions",
#     1],
#    ['Person', 'Harry', 'Reminded of', 'Person', 'Dudley', -1],
#    ['Person', 'Harry', 'Holding', 'Object', 'bag full of money', 1],
#    ['Person',
#     'Harry',
#     'Interacted with',
#     'Person',
#     'boy with a pale, pointed face',
#     1],
#    ['Person', 'Hagrid', 'Picked up', 'Object', 'grubby little package', 1],
#    ['Person', 'Hagrid', 'Tucked inside', 'Object', 'grubby little package', 1],
#    ['Person', 'Harry', 'Interacted with', 'Person', 'Madam Malkin', 1]]],
#  ["Harry meets a boy who is arrogant and talks about his plans to get a racing broom and play Quidditch. The boy assumes he will be in Slytherin House and makes negative comments about Hufflepuff. Harry dislikes the boy's attitude, especially when he insults Hagrid, the Hogwarts gamekeeper.",
#   63,
#   [['Person', 'Harry', 'Knows', 'Person', 'Hagrid', 1],
#    ['Person', 'Harry', 'Disagrees with', 'Person', 'boy', 1],
#    ['Person', 'Hagrid', 'Works at', 'Place', 'Hogwarts', 1],
#    ['Person', 'Hagrid', 'Located in', 'Place', 'Hogwarts', -1]]],
#  ["Harry encounters a boy who expresses disdain for those from non-wizarding families, implying they shouldn't attend Hogwarts. Despite Harry's discomfort, he briefly engages with the boy before leaving. Later, Harry asks Hagrid about Quidditch and shares his encounter with the boy, who wrongly assumed Harry is from a Muggle family.",
#   64,
#   [['Person', 'boy', 'Mentions Muggle families', 'Person', 'Harry', 0],
#    ['Person', 'Harry', 'Avoids conversation with', 'Person', 'boy', 1],
#    ['Person', 'boy', 'Expresses disdain towards', 'Person', 'Harry', -1],
#    ['Person', 'Harry', 'FamilyRelation', 'Person', 'Dudley', -1],
#    ['Person', 'Harry', 'Interacts with', 'Person', 'Hagrid', 1],
#    ['Person', 'Harry', 'Shares information with', 'Person', 'Hagrid', 1],
#    ['Person', 'Harry', 'Asks about Quidditch', 'Person', 'Hagrid', 1]]],
#  ['The text discusses various aspects of the wizarding world, including Quidditch, Hogwarts School Houses (Slytherin and Hufflepuff), and the bookshop Flourish and Blotts. Hagrid introduces Harry to these concepts and warns him about Slytherin House, known for producing dark wizards. Harry is intrigued by the magical books, including one on curses.',
#   65,
#   [['Person', 'Harry', 'HasSpellEffect', 'Spell', 'Tongue Tying Curse', 0],
#    ['Person', 'Harry', 'Studies', 'Spell', 'Curses and Counter curses', -1],
#    ['Person', 'Harry', 'AuthorOf', 'Spell', 'Professor Vindictus Viridian', 0],
#    ['Person', 'Harry', 'HouseAffiliation', 'House', 'Hufflepuff', 0],
#    ['Person', 'Harry', 'HasSpellEffect', 'Spell', 'Hair Loss Curse', 0],
#    ['Person', 'Hagrid', 'Possession', 'Object', 'wand', -1],
#    ['Person', 'Harry', 'HasSpellEffect', 'Spell', 'Jelly Legs Curse', 0],
#    ['Person', 'Harry', 'Rivalry', 'House', 'Slytherin', 1]]],
#  ['Hagrid advises Harry not to use magic in the Muggle world unless necessary and tells him he needs more study to perform curses. They shop for potion ingredients and a wand, with Hagrid suggesting an owl as a birthday present instead of a toad or cat. They visit Eeylops Owl Emporium and leave with an owl.',
#   66,
#   [['Person', 'Hagrid', 'Gifts', 'Object', 'owl', 1],
#    ['Person', 'Harry', 'Possession', 'Object', 'scales', -1],
#    ['Person', 'Harry Potter', 'Obtains', 'Object', 'Magic Wand', 1],
#    ['Person', 'Harry', 'Examines', 'Object', 'beetle eyes', -1],
#    ['Person', 'Harry', 'Possession', 'Object', 'brass telescope', -1],
#    ['Person', 'Harry', 'Examines', 'Object', 'silver unicorn horns', -1],
#    ['Person', 'Harry', 'Desired', 'Object', 'solid gold cauldron', -1]]],
# ...
#    ['Person', 'Troy', 'Drops', 'Person', 'Moran', -1],
#    ['Person', 'Troy', 'Passes to', 'Person', 'Moran', 1],
#    ['Person', 'Troy', 'Lap of honor', 'QuidditchTeam', 'Ireland', 0],
#    ['Person', 'Troy', 'Plays for', 'QuidditchTeam', 'Ireland', 1],
#    ['Person', 'Troy', 'Scores for', 'QuidditchTeam', 'Ireland', 1]]],
#  ["The match between Bulgaria and Ireland intensifies as the Bulgarian Beaters aggressively target the Irish Chasers. Despite the chaos, Bulgaria scores their first goal. The veela's celebration distracts the players, leading to a dangerous moment between the Seekers Krum and Lynch. Lynch crashes to the ground, causing concern among the spectators. Mediwizards rush to aid Lynch as the game is temporarily paused.",
#   981,
#   [['Person', 'Vulchanov', 'Friendship', 'Person', 'Ivanova', 0],
#    ['Person', 'Volkov', 'ParticipatesInEvent', 'Person', 'Vulchanov', -1],
#    ['Person', 'Krum', 'KilledBy', 'Person', 'Lynch', 0],
#    ['Person', 'Ivanova', 'Friendship', 'Person', 'Vulchanov', 0],
#    ['Person', 'Harry', 'Observes', 'Person', 'Krum', 1],
#    ['Person', 'Krum', 'Rivalry', 'Person', 'Lynch', 1],
#    ['Person', 'Ivanova', 'PerformsSpell', 'Person', 'Ryan', 0],
#    ['Person', 'Krum', 'WitnessesEvent', 'Person', 'Lynch', -1],
#    ['Person', 'Ivanova', 'Rivalry', 'Person', 'Ryan', 0],
#    ['Person', 'Vulchanov', 'ParticipatesInEvent', 'Person', 'Volkov', -1],
#    ['Person', 'Krum', 'ParticipatesInEvent', 'Person', 'Lynch', -1],
#    ['Person', 'Ivanova', 'Friendship', 'Person', 'Volkov', 0],
#    ['Person', 'Vulchanov', 'Friendship', 'Person', 'Volkov', 0],
#    ['Person', 'Volkov', 'Friendship', 'Person', 'Ivanova', 0],
#    ['Person', 'Ivanova', 'VictimOfSpell', 'Person', 'Ryan', 0]]],
#  ["Harry uses his Omnioculars to closely observe the Quidditch match between Krum and Lynch. Krum's flying skills impress Harry as he maneuvers effortlessly through the air. Lynch is revived after a dangerous dive, and Ireland gains the lead in the game. The match becomes more intense and aggressive as fouls are committed.",
#   982,
#   [['Person', 'Mullet', 'Possesses', 'Object', 'Quaffle', 1],
#    ['Person', 'Harry', 'Watches', 'Object', 'Quaffle', -1],
#    ['Person', 'Krum', 'Competes with', 'Person', 'Lynch', 1],
#    ['Person',
#     'Hassan Mostafa',
#     'Acting oddly',
#     'MagicalCreature',
#     'Veela',
#     -1],
#    ['Person', 'Mullet', 'Encounters', 'Person', 'Zograf', 1],
#    ['Person', 'Mostafa', 'Blows', 'Object', 'Whistle', 1]]],
#  ['Mostafa confronts the Bulgarian Keeper for using elbows excessively, resulting in a penalty for Ireland. Chaos ensues as the leprechauns and veela react, with the referee getting involved and attempting to send off the Bulgarian team mascots.',
#   983,
#   [['Person', 'Volkov', 'Argument', 'Person', 'Mostafa', 1],
#    ['Person', 'Hassan Mostafa', 'Informed by', 'Person', 'Ludo Bagman', -1],
#    ['Person',
#     'Hassan Mostafa',
#     'Embarrassed by',
#     'MagicalCreature',
#     'Veela',
#     1],
#    ['Person', 'Ludo Bagman', 'Informs', 'Person', 'Hassan Mostafa', -1],
#    ['Person', 'Hassan Mostafa', 'Shouted at', 'MagicalCreature', 'Veela', 1],
#    ['Person', 'Mediwizard', 'Kicks', 'Person', 'Hassan Mostafa', 0],
#    ['Person', 'Hassan Mostafa', 'Kicked by', 'Person', 'Mediwizard', 0]]],
#  ['The Bulgarian Beaters argue with Mostafa, leading to penalties for Ireland. The match intensifies with aggressive play and fouls. The veela lose control and attack the leprechauns with fire, losing their beauty.',
#   984,
#   [['Person', 'Dimitrov', 'Collision', 'Person', 'Moran', 1],
#    ['Person', 'Vulchanov', 'Argument', 'Person', 'Mostafa', 1],
#    ['Person',
#     'Mr Weasley',
#     'Yelled over',
#     'Organisation',
#     'Ministry wizards',
#     -1],
#    ['Person', 'Volkov', 'Teammates', 'Person', 'Vulchanov', 1],
#    ['Person', 'Dimitrov', 'Penalty', 'Person', 'Moran', -1],
#    ['Person', 'Dimitrov', 'Foul', 'Person', 'Moran', 1]]],
#  ['During a Quidditch match, chaos ensues as veela and leprechauns cause a commotion, while players battle fiercely on the field. Amidst the intense game, injuries occur, distractions arise, and the Seeker spots the Snitch, leading to a thrilling chase.',
#   985,
#   [['Person', 'Ron', 'Felt the same', 'Person', 'Harry', 0],
#    ['Person', 'Irish Seeker', 'Seen', 'Miscellaneous', 'Snitch', 1],
#    ['Person', 'Irish Beater Quigley', 'Hits Bludger', 'Person', 'Krum', 1],
#    ['Person', 'Harry', 'Staring through', 'Object', 'Omnioculars', 1],
#    ['Person', 'Harry', 'Realize injured', 'Person', 'Krum', -1],
#    ['Person', 'Krum', 'Gets', 'Object', 'Snitch', -1],
#    ['Person', 'Krum', 'Set alight', 'Object', 'Broom tail', 0]]],
#  ['During a Quidditch match, Krum catches the Snitch but Ireland wins as they were already ahead by 160 points. The crowd erupts in delight as the unexpected outcome unfolds.',
#   986,
#   [['Person', 'Krum', 'Catches', 'Object', 'Snitch', 1],
#    ['Person', 'Krum', 'Member of', 'QuidditchTeam', 'Bulgaria', 1],
#    ['QuidditchTeam', 'Ireland', 'Wins', 'Event', 'Quidditch Match', 1],
#    ['Person', 'Krum', 'WitnessesEvent', 'Event', 'Quidditch World Cup', -1]]],
#  ["The Irish Chasers dominated the Quidditch match, with Krum refusing medical help despite looking injured. The Bulgarian team was dejected as the Irish celebrated their victory. The Bulgarian Minister of Magic revealed he could speak English, much to Fudge's annoyance. The Irish team paraded with the Quidditch World Cup, and Bulgaria was praised as gallant losers.",
#   987,
#   [['Person', 'Krum', 'Friendship', 'Person', 'Hermione', -1],
#    ['Person', 'Krum', 'Friendship', 'Person', 'Fudge', 0],
#    ['Person', 'Aidan Lynch', 'Supporting', 'Person', 'Moran', 0],
#    ['Person', 'Krum', 'Friendship', 'Person', 'Bagman', 0]]],
#  ['Bagman announces the defeated Bulgarian players and the victorious Irish team at the Quidditch World Cup, with Krum looking injured but receiving a loud cheer. The Irish team celebrates their win as Fred and George approach Bagman, hinting at a financial exchange.',
#   988,
#   [['Person', 'George', 'Standing in front', 'Person', 'Ludo Bagman', 1],
#    ['Person', 'Aidan Lynch', 'Supporting', 'Person', 'Connolly', 0],
#    ['Person', 'Fred', 'Standing in front', 'Person', 'Ludo Bagman', 1],
#    ['Person', 'Fred', 'Sibling', 'Person', 'George', 1],
#    ['Person', 'Aidan Lynch', 'Lifting', 'Person', 'Quigley', 0],
#    ['Person', 'Aidan Lynch', 'Lifting', 'Person', 'Troy', 0]]],
#  ['Mr. Weasley warns Fred and George not to tell their mother about their gambling winnings. They return to their campsite after a Quidditch match, where they enjoy hot chocolate and lively discussions before going to bed. Harry lies awake in his bunk, reminiscing about the match and watching leprechaun lanterns fly overhead.',
#   989,
#   [['Person', 'Fred', 'Got big plans', 'Person', 'George', 0],
#    ['Person', 'Fred', 'Confiscated money', 'Person', 'George', 0],
#    ['Person', 'George', 'Implored by', 'Person', 'Mr Weasley', 1],
#    ['Person', 'Fred', 'Arguing enjoyably', 'Person', 'George', 0],
#    ['Person', 'George', 'Father', 'Person', 'Mr Weasley', -1],
#    ['Person', 'Ginny', 'Called a halt', 'Person', 'Mr Weasley', 0],
#    ['Person', 'Fred', 'Decided not to know', 'Person', 'George', 0],
#    ['Person', 'Harry', 'Clambered into', 'Person', 'Ron', 0],
#    ['Person', 'Harry', 'Friend', 'Person', 'Ron', -1],
#    ['Person',
#     'Mr Weasley',
#     'Disagreement about cobbing',
#     'Person',
#     'Charlie',
#     0],
#    ['Person', 'Fred', 'Sibling', 'Person', 'George', 1],
#    ['Person', 'Harry', 'Staring up', 'Person', 'Ron', 0],
#    ['Person', 'Fred', 'Implored', 'Person', 'George', 0],
#    ['Person', 'Fred', 'Father', 'Person', 'Mr Weasley', 0],
#    ['Person', 'Harry', 'Watching the glow', 'Person', 'Ron', 0],
#    ['Person', 'Ginny', 'Daughter', 'Person', 'Mr Weasley', -1],
#    ['Person', 'Hermione', 'Went into', 'Person', 'Ginny', 0],
#    ['Person', 'Fred', 'Implored by', 'Person', 'Mr Weasley', 1],
#    ['Person', 'Harry', 'Picturing moves', 'Person', 'Ron', 0],
#    ['Person', 'Harry', 'Friend', 'Person', 'Mr Weasley', 0],
#    ['Person', 'Ginny', 'Fell asleep', 'Person', 'Mr Weasley', 0],
#    ['Person', 'Oliver Wood', 'Fails to convey', 'Spell', 'Wronski Feint', 0]]],
#  ['Harry is excited to try out the Wronski Feint on his Firebolt, imagining himself flying in a Quidditch match. However, his thoughts are interrupted when Mr. Weasley urgently wakes him up, revealing chaos in the campsite with people fleeing from hooded figures casting spells and causing havoc.',
#   990,
#   [['Person', 'Mr Roberts', 'Parent of', 'Person', 'Muggle child', 1],
#    ['Person', 'Harry', 'Sees', 'Spell', 'green light', 1],
#    ['Person', 'Harry', 'Wears', 'Object', 'robes', 1],
#    ['Person', 'Harry', 'Introduced by', 'Person', 'Ludo Bagman', 0],
#    ['Person', 'Harry', 'Observes', 'Person', 'wizards', 1],
#    ['Person', 'Harry', 'Dreams of', 'Person', 'Krum', 0],
#    ['Person', 'Harry', 'Moves into', 'Place', 'woods', 1],
#    ['Person', 'Harry', 'Located in', 'Place', 'campsite', 1],
#    ['Person', 'Harry', 'Moves across', 'Place', 'field', 1],
#    ['Person', 'Harry', 'Instructed by', 'Person', 'Mr Weasley', 1],
#    ['Person', 'Harry', 'Awakened by', 'Person', 'Mr Weasley', 1]]],
#  ['A chaotic scene unfolds at the campsite as masked wizards control floating people like marionettes, causing destruction and chaos. The Weasley family and Ministry wizards rush to intervene and protect the campers, with Fred leading Ginny towards safety in the woods.',
#   991,
#   [['Person', 'Fred', 'Sibling of', 'Person', 'Ginny', -1],
#    ['Person', 'Fred', 'Supports', 'Person', 'Ginny', 1],
#    ['Person', 'Mrs Roberts', 'Parent of', 'Person', 'Muggle child', 1],
#    ['Person', 'Harry', 'Friendship', 'Person', 'Ron', -1]]],
#  ['Harry, Ron, Hermione, and George are at a crowded event where Ministry wizards are struggling to reach hooded wizards in the center. Chaos ensues as lanterns are extinguished, people are pushing and shouting, and Ron trips over a tree root. Draco Malfoy appears and exchanges tense words with Ron and Hermione, hinting at danger for Muggles.',
#   992,
#   [['Person', 'Ron', 'Friendship', 'Person', 'Hermione', 1],
#    ['Person', 'Ron', 'Rivalry', 'Person', 'Draco Malfoy', 1],
#    ['Person', 'Ron', 'Friendship', 'Person', 'George', -1],
#    ['Person', 'Draco Malfoy', 'Rivalry', 'Person', 'Hermione', 1],
#    ['Person', 'Ron', 'Friendship', 'Person', 'Harry', -1],
#    ['Person', 'Harry', 'Rivalry', 'Person', 'Draco Malfoy', -1],
#    ['Person', 'Hermione', 'Rivalry', 'Person', 'Draco Malfoy', 1],
#    ['Person', 'Harry', 'Friendship', 'Person', 'Hermione', -1]]],
#  ["The text describes a confrontation between Harry, Hermione, Ron, and Malfoy in which Malfoy uses offensive language towards Hermione. There is tension and fear in the air as a loud noise startles everyone. Hermione tries to defuse the situation and leads Harry and Ron away, while Ron expresses anger towards Malfoy. The group discusses the whereabouts of others and speculates about Malfoy's father being involved in a masked group.",
#   993,
#   [['Person', 'Malfoy', 'Rivalry', 'Person', 'Ron', 1],
#    ['Person', 'Malfoy', 'Rivalry', 'Person', 'Harry', 1],
#    ['Person', 'Malfoy', 'Rivalry', 'Person', 'Hermione', 1],
#    ['Person', 'Fred', 'Sibling', 'Person', 'George', -1]]],
#  ['Fred, George, and Ginny are missing at the campsite. Harry, Ron, and Hermione encounter a group of teenagers from Beauxbatons Academy of Magic who are looking for Madame Maxime. Harry realizes he has lost his wand and feels vulnerable without it. Winky the house elf appears nearby.',
#   994,
#   [['Person', 'Winky', 'Bewitched by', 'Person', 'Mr Crouch', -1],
#    ['Person', 'Ron', 'Friendship', 'Person', 'Hermione', 1],
#    ['Person', 'Winky', 'Encounter', 'Person', 'Harry', 1],
#    ['Person', 'Harry', 'Friendship', 'Person', 'Ron', -1],
#    ['Person', 'George', 'Sibling', 'Person', 'Ginny', -1],
#    ['Person', 'George', 'Friendship', 'Person', 'Harry', -1],
#    ['Person', 'Fred', 'Sibling', 'Person', 'Ginny', -1],
#    ['Person', 'Ginny', 'Friendship', 'Person', 'Harry', -1],
#    ['Person', 'Harry', 'Friendship', 'Person', 'Hermione', -1],
#    ['Person', 'Fred', 'Friendship', 'Person', 'Harry', -1]]],
#  ['Winky, a house elf, is struggling to run due to an invisible force holding her back. Hermione expresses outrage at the treatment of house elves, while Ron believes they are content with their servitude. The trio continues through the woods, wary of potential danger.',
#   995,
#   [['Person', 'Winky', 'Made to trample tents', 'Person', 'Mr Crouch', -1],
#    ['Person', 'Winky', 'Hotly argued with', 'Person', 'Hermione', 0],
#    ['Person', 'Ginny', 'Searched for', 'Person', 'Harry', -1],
#    ['MagicalCreature', 'goblins', 'Possesses', 'Object', 'sack of gold', -1],
#    ['Person', 'Malfoy', 'Said truth about', 'Person', 'Hermione', 0],
#    ['Person', 'Harry', 'Saw truth in', 'Person', 'Hermione', 0],
#    ['Person', 'Ron', 'Disagreed with', 'Person', 'Hermione', 1],
#    ['Person', 'Winky', 'Forced to go up', 'Person', 'Mr Crouch', -1],
#    ['Person', 'Ron', 'Glanced edgily at', 'Person', 'Hermione', 0],
#    ['Person', 'Fred', 'Searched for', 'Person', 'Harry', -1],
#    ['Person', 'Winky', 'Terrified by', 'Person', 'Mr Crouch', -1],
#    ['Person', 'George', 'Searched for', 'Person', 'Harry', -1]]],
#  ['A group of goblins celebrate winning gold from a match, while young wizards boast about their achievements. Harry, Ron, and Hermione encounter veela and arrogant wizards in the woods, including Stan Shunpike and Ludo Bagman.',
#   996,
#   [['Person', 'Ron', 'Invents', 'Object', 'broomstick', 0],
#    ['Person', 'Harry', 'Witnesses', 'Person', 'Ron', 1],
#    ['Person', 'Harry', 'Restrains', 'Person', 'Hermione', 0],
#    ['Person', 'Ron', 'Reaches', 'Place', 'Jupiter', 0],
#    ['Person',
#     'young wizards',
#     'Member of',
#     'Organisation',
#     'Ministry of Magic',
#     -1],
#    ['Person', 'Harry', 'observes', 'Person', 'Bagman', 1],
#    ['Person', 'Ludo Bagman', 'Emerges from', 'Place', 'behind a tree', 1],
#    ['Person',
#     'young wizards',
#     'Member of',
#     'Organisation',
#     'Committee for the Disposal of Dangerous Creatures',
#     0],
#    ['Person',
#     'young wizards',
#     'Employee of',
#     'Organisation',
#     'Leaky Cauldron',
#     0],
#    ['Person',
#     'Stan Shunpike',
#     'Works on',
#     'Object',
#     'triple decker Knight Bus',
#     -1],
#    ['Person', 'young wizards', 'Possesses', 'Object', 'sacks of Galleons', -1],
#    ['Person', 'Hermione', 'Restrains', 'Person', 'Ron', 0]]],
#  ["Harry notices a change in Bagman's demeanor as he appears distressed. Ron informs Bagman about a riot at the campsite involving Muggles. Bagman leaves abruptly. Hermione questions Bagman's competence, while Ron praises his skills as a Beater. The trio discusses the situation and expresses concern for the Muggles involved in the riot.",
#   997,
#   [['Person', 'Ron', 'sits next to', 'Person', 'Harry', 0],
#    ['Person', 'Ron', 'Friendship', 'Person', 'Hermione', 1],
#    ['Person', 'Harry', 'sits next to', 'Person', 'Hermione', 0],
#    ['Person', 'Harry', 'sits next to', 'Person', 'Ron', 0],
#    ['Person', 'Ron', 'sits next to', 'Person', 'Hermione', 0],
#    ['Person', 'Hermione', 'comments on', 'Person', 'Bagman', 1],
#    ['Person', 'Ron', 'mentions', 'Person', 'Bagman', 1]]],
#  ['Harry, Ron, and Hermione are in the woods when they witness a mysterious and frightening event - a colossal skull with a serpent emerging from its mouth appears in the sky, causing chaos and screams around them.',
#   998,
#   [['Person', 'Harry', 'Friendship', 'Person', 'Hermione', 1],
#    ['Person', 'Harry', 'Friendship', 'Person', 'Ron', 1],
#    ['Person', 'Harry', 'PerformsSpell', 'Spell', 'MORSMORDREl', 0]]],
#  ["Harry, Hermione, and Ron are ambushed by twenty wizards with wands pointed at them, but Mr. Weasley intervenes to stop the attack, revealing Mr. Crouch's involvement.",
#   999,
#   [['Person', 'Harry', 'Unknown', 'Person', 'Mr Crouch', -1],
#    ['Person', 'Harry', 'FamilyRelation', 'Person', 'Mr Weasley', 0],
#    ['Person', 'Harry', 'Enemy of', 'Person', 'Voldemort', -1]]]]

# %%
import json

file_path = './data/jsonl/hp.jsonl'

# 打开并读取 .jsonl 文件
with open(file_path, 'r', encoding='utf-8') as file:
    data = []
    # 每一行都是一个 JSON 对象，将其读取并解析为 Python 字典
    for line in file:
        json_object = json.loads(line.strip())  # strip() 去掉换行符
        data.append(json_object)

hp_text_list_all = [json_object['text'] for json_object in data]

# %%
hp_text_list_all[0]
# Out:
# 'Chapter : THE BOY WHO LIVED .  Mr and Mrs Dursley , of number four , Privet Drive , were proud to say that they were perfectly normal , thank you very much .  They were the last people you’d expect to be involved in anything strange or mysterious , because they just didn’t hold with such nonsense .  Mr Dursley was the director of a firm called Grunnings , which made drills .  He was a big , beefy man with hardly any neck , although he did have a very large mustache .  Mrs Dursley was thin and blonde and had nearly twice the usual amount of neck , which came in very useful as she spent so much of her time craning over garden fences , spying on the neighbors .  The Dursley s had a small son called Dudley and in their opinion there was no finer boy anywhere .  The Dursleys had everything they wanted , but they also had a secret , and their greatest fear was that somebody would discover it .  They didn’t think they could bear it if anyone found out about the Potters .  Mrs Potter was Mrs Dursley’s sister , but they hadn’t met for several years in fact , Mrs Dursley pretended she didn’t have a sister , because her sister and her good for nothing husband were as unDursleyish as it was possible to be .  The Dursleys shuddered to think what the neighbors would say if the Potters arrived in the street .  The Dursleys knew that the Potters had a small son , too , but they had never even seen him .  This boy was another good reason for keeping the Potters away they didn’t want Dudley mixing with a child like that .  When Mr and Mrs Dursley woke up on the dull , gray Tuesday our story starts , there was nothing about the cloudy sky outside to suggest that strange and mysterious things would soon be happening all over the country .  Mr Dursley hummed as he picked out his most boring tie for work , and Mrs Dursley gossiped away happily as she wrestled a screaming Dudley into his high chair .  None of them noticed a large , tawny owl flutter past the window .'

# %%
all_list_kg[:10]
# Out:
# [["Mr and Mrs Dursley, a seemingly normal couple living on Privet Drive, have a secret fear of their neighbors discovering the Potters, Mrs Dursley's unconventional sister and her family. They are particularly concerned about their son Dudley mixing with the Potters' son. One day, as they go about their mundane routines, unaware of the magical events about to unfold, a tawny owl flies past their window.",
#   0,
#   [['Person', 'Mrs Dursley', 'Sisters', 'Person', 'Mrs Potter', 1],
#    ['Person', 'Mr Dursley', 'Parent of', 'Person', 'Dudley', 1],
#    ['Person', 'Mr Dursley', 'Spouse of', 'Person', 'Mrs Dursley', 1],
#    ['Person', 'Mrs Potter', 'Parent of', 'Person', 'Harry Potter', 1]]],
#  ['Mr. Dursley leaves his house in a rush, noticing strange occurrences like a cat reading a map and people dressed in cloaks. He dismisses these oddities as tricks of the light and new fashion trends, but is increasingly irritated by the unusual sights around him.',
#   1,
#   [['Person', 'Mr Dursley', 'Witnesses', 'MagicalCreature', 'Cat', 1],
#    ['Person', 'Mr Dursley', 'Fear flooded', 'Person', 'Harry Potter', -1]]],
#  ['Mr. Dursley goes about his day, oblivious to strange occurrences involving owls and people in cloaks. However, he becomes alarmed upon overhearing a conversation about the Potters and their son, Harry, leading to a sense of fear and unease.',
#   2,
#   [['Person', 'Mr Dursley', 'Uncertain Relationship', 'Person', 'Harry', 0],
#    ['Person', 'Mr Dursley', 'He looked back', 'Person', 'Harry Potter', 0],
#    ['Person',
#     'Mr Dursley',
#     'Overhear Conversation',
#     'Person',
#     'Harry Potter',
#     1],
#    ['Person', 'Mr Dursley', 'Fear flooded', 'Person', 'Harry Potter', 1]]],
#  ['Mr. Dursley is unsure about his nephew\'s name, worries about strange people in cloaks, and encounters a peculiar old man who mentions "You Know Who" leaving. He is confused by the term "Muggle" and is further unsettled by a cat\'s behavior in his garden.',
#   3,
#   [['Person', 'Mr Dursley', 'Uncertain Relationship', 'Person', 'Harry', 0],
#    ['Person', 'Mr Dursley', 'Spouse of', 'Person', 'Mrs Dursley', -1]]],
#  ['Mr. Dursley tries to act normal after hearing strange news about owls and shooting stars, but eventually asks his wife about her sister, leading to a shocked and angry reaction.',
#   4,
#   [['Person', 'Mrs Dursley', 'Parent of', 'Person', 'Dudley', -1],
#    ['Person', 'Mr Dursley', 'Spouse of', 'Person', 'Mrs Dursley', 1],
#    ['Person', 'Mr Dursley', 'Parent of', 'Person', 'Dudley', -1],
#    ['Person', 'Mrs Dursley', 'Sister of', 'Person', 'Petunia', 0],
#    ['Person', 'Mrs Dursley', 'Sister of', 'Person', 'Lily', 1]]],
#  ['Mr. and Mrs. Dursley discuss strange occurrences in town related to the Potters, particularly their son Harry. Mr. Dursley is worried about the potential connection to the Potters and hopes they will not come near him and his wife due to their negative opinions about them.',
#   5,
#   [['Person', 'Harry Potter', 'Related to', 'Person', 'Petunia', 1],
#    ['Person', 'Mrs Dursley', 'Mentioned name', 'Person', 'Harry Potter', 1],
#    ['Person', 'Petunia', 'FamilyRelation', 'Person', 'Harry Potter', 1],
#    ['Person', 'Mr Dursley', 'Mentioned name', 'Person', 'Harry Potter', 1],
#    ['Person', 'Mr Dursley', 'Negative about', 'Person', 'Harry Potter', 1]]],
#  ['A mysterious man named Albus Dumbledore arrives on Privet Drive, catching the attention of a cat. Despite the unwelcoming atmosphere, Dumbledore seems unfazed as he performs a magical act with a silver cigarette lighter, causing a street lamp to go out.',
#   6,
#   [['Person', 'Cat', 'WitnessesEvent', 'Person', 'Albus Dumbledore', 1],
#    ['Person', 'Dumbledore', 'Meets', 'Person', 'Professor McGonagall', 1],
#    ['Person',
#     'Albus Dumbledore',
#     'Possession',
#     'Object',
#     'Silver cigarette lighter',
#     0],
#    ['Person',
#     'Albus Dumbledore',
#     'Performs magical act with',
#     'Object',
#     'Silver cigarette lighter',
#     1],
#    ['Person', 'Professor McGonagall', 'Possession', 'Person', 'Cat', -1]]],
#  ["Dumbledore uses a device to darken street lamps and reveals Professor McGonagall in cat form. They discuss the celebration of Voldemort's downfall and the Muggles' awareness of magical events. McGonagall is annoyed by the lack of secrecy.",
#   7,
#   [['Person', 'Professor McGonagall', 'Possession', 'Person', 'Cat', 0],
#    ['Person',
#     'Professor McGonagall',
#     'Possession',
#     'MagicalCreature',
#     'Cat',
#     1],
#    ['Person', 'Dumbledore', 'Rivalry', 'Person', 'Voldemort', 1]]],
#  ['Dumbledore and Professor McGonagall discuss the disappearance of Voldemort and the fear of saying his name. McGonagall is concerned about people being careless and revealing the wizarding world to Muggles. Dumbledore offers her a lemon drop and encourages using Voldemort\'s name instead of "You Know Who." McGonagall admires Dumbledore\'s bravery in facing Voldemort.',
#   8,
#   [['Person', 'McGonagall', 'Fear', 'Person', 'Voldemort', 1],
#    ['Person',
#     'Professor McGonagall',
#     'Friendship',
#     'Person',
#     'Dumbledore',
#     1]]],
#  ["Professor McGonagall expresses disbelief at the rumors surrounding Voldemort's disappearance, specifically regarding the fate of Lily and James Potter and their son Harry. She struggles to comprehend how Voldemort, after all his atrocities, could not kill a little boy, leading to his downfall. Dumbledore remains silent, confirming the truth of the rumors.",
#   9,
#   [['Person', 'Voldemort', 'TravelTo', 'Place', "Godric's Hollow", -1],
#    ['Person', 'Voldemort', 'Breaks', 'Miscellaneous', "Voldemort's power", 0],
#    ['Person',
#     'Harry Potter',
#     'Breaks',
#     'Miscellaneous',
#     "Voldemort's power",
#     1],
#    ['Person', 'Voldemort', 'FailedToKill', 'Person', 'Harry Potter', 1],
#    ['Person', 'Voldemort', 'VictimOfSpell', 'Person', 'James Potter', 1],
#    ['Person', 'Harry Potter', 'Interacts with', 'Person', 'McGonagall', 0],
#    ['Person', 'Voldemort', 'VictimOfSpell', 'Person', 'Lily Potter', 1],
#    ['Person', 'Voldemort', 'VictimOfSpell', 'Person', 'Harry Potter', 1]]]]

# %%
entity_rel_map_val = {
    't': set(),
    'f': set(),
    'n':set()
}

# %%
for item in all_list_kg:
    result_list = item[-1]
    for result in result_list:
        if result[-1] == 1:
            entity_rel_map_val['t'].add(tuple(result[:-1]))
        elif result[-1] == 0:
            entity_rel_map_val['f'].add(tuple(result[:-1]))
        else:
            entity_rel_map_val['n'].add(tuple(result[:-1]))

# %%
entity_rel_map_val
# Out:
# {'t': {('Person', 'Uncle Vernon', 'Notices', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Student-Teacher', 'Person', 'Professor Lupin'),
#   ('Person', 'Harry', 'VictimOfSpell', 'Person', 'Sirius Black'),
#   ('Person',
#    'Ron',
#    'Comments on',
#    'Miscellaneous',
#    'Defense Against the Dark Arts lesson'),
#   ('Person', 'Ron', 'Explains', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Pointing', 'Object', 'table'),
#   ('Person',
#    'Harry',
#    'Entered',
#    'Place',
#    "Madam Malkin's Robes for All Occasions"),
#   ('Person', 'Harry Potter', 'Possession', 'Object', 'Stone'),
#   ('Person', 'Snape', 'Goes through', 'Object', 'trapdoor'),
#   ('Person', 'Harry', 'is left on', 'Place', 'Privet Drive'),
#   ('Person', 'Harry', 'Instructed by', 'Person', 'Mr Weasley'),
#   ('Person', 'Harry', 'Mentions', 'Person', 'Dumbledore'),
#   ('Person', 'Quirrell', 'Master', 'Person', 'Voldemort'),
#   ('Person', 'Harry Potter', 'Famous because of', 'Person', 'Voldemort'),
#   ('Person', 'Ron', 'Fills', 'Object', 'teacup'),
#   ('Person', 'Fudge', 'Meets', 'Person', 'Bulgarian Minister of Magic'),
#   ('Person', 'Harry', 'Friendship', 'MagicalCreature', 'Fawkes'),
#   ('Person', 'Professor McGonagall', 'Intervention', 'Person', 'Ron'),
#   ('Person', 'Hermione', 'Buys', 'Object', 'enormous ginger cat'),
#   ('Person', 'Harry', 'Summons', 'MagicalCreature', 'Patronus'),
#   ('Person', 'Dumbledore', 'Instructs to not be seen', 'Person', 'Hermione'),
#   ('Person', 'Snape', 'Looks at', 'Person', 'Lockhart'),
#   ('Person', 'Hermione', 'Keeps company', 'Person', 'Harry'),
#   ('Person', 'Harry', 'marking closely', 'Person', 'Malfoy'),
#   ('Person', 'Harry', 'FamilyRelation', 'Person', 'Aunt Marge'),
#   ('Person', 'Hagrid', 'LocatedIn', 'Place', 'Forbidden Forest'),
#   ('Person', 'Harry', 'Explains later', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Moves across', 'Place', 'field'),
#   ('Person', 'Harry', 'Tramps up to', 'Place', 'Leaky Cauldron'),
#   ('Person', 'Fred', 'Friend of', 'Person', 'Harry'),
#   ('Person', 'Ron', 'frowned after', 'Person', 'Hermione'),
#   ('Person', 'Filch', 'Owns', 'MagicalCreature', 'Mrs Norris'),
#   ('Person', 'Hermione', 'Concerned for', 'Person', 'Harry'),
#   ('Person', 'James Potter', 'Played joke', 'Person', 'Severus Snape'),
#   ('Person', 'Harry', 'Observes', 'Place', 'Stadium'),
#   ('Person', 'Professor Trelawney', 'Joins', 'Person', 'Parvati'),
#   ('Person', 'Harry', 'Mentor-like', 'Person', 'Dumbledore'),
#   ('Person', 'Mr Weasley', 'FamilyRelation', 'Person', 'Fred'),
#   ('Person', 'Harry', 'Staring at', 'Person', 'Malfoy'),
#   ('Person', 'Malfoy', 'Attempts to stop', 'Person', 'Harry'),
#   ('Person', 'Professor Flitwick', 'Conducts', 'Event', 'Practical exams'),
#   ('Person', 'Amos Diggory', 'FamilyRelation', 'Person', 'Cedric Diggory'),
#   ('Person', 'Harry', 'Timely arrival', 'MagicalCreature', 'Fawkes'),
#   ('Person', 'Harry', 'Said Wood', 'Person', 'Wood'),
#   ('Person', 'Hagrid', 'Worried about', 'MagicalCreature', 'Buckbeak'),
#   ('Person', 'Ron', 'Encountered', 'Person', 'Snape'),
#   ('Person', 'Ron', 'Possesses', 'Object', 'wand'),
#   ('Person', 'Ron', 'Describes', 'Object', 'sugar quills'),
#   ('Person', 'Draco Malfoy', 'Friendship', 'Person', 'Crabbe'),
#   ('House', 'Gryffindor', 'Under the eye of', 'Person', 'Madam Hooch'),
#   ('Person', 'Salazar Slytherin', 'FounderOf', 'Place', 'Hogwarts'),
#   ('Person', 'Ron', 'Possession', 'Object', 'Acid Pops'),
#   ('Person', 'Hermione', 'Snapped at', 'Person', 'Ron'),
#   ('Person', 'Ron', 'Expresses disbelief', 'Person', 'Ginny'),
#   ('Person', 'Wormtail', 'Killed her', 'Person', 'Bertha Jorkins'),
#   ('Person', 'Myrtle', 'Located in', 'Place', 'U bend'),
#   ('Person', 'Harry', 'Behind', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Acquaintance', 'Person', 'Professor Snape'),
#   ('Person', 'Ron', 'Parent', 'Person', 'Mother'),
#   ('Person', 'Harry', 'WitnessesEvent', 'Event', 'exam results'),
#   ('Person', 'Mr Weasley', 'Greets', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Rivalry', 'Person', 'Draco Malfoy'),
#   ('Person', 'Fred', 'Lands next to', 'Place', "Ron's house"),
#   ('Person', 'Hagrid', 'Tells', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Heaves trunk', 'Person', 'Fred'),
#   ('Person', 'Fred', 'FamilyRelation', 'Person', 'Percy'),
#   ('Person', 'Harry', 'WitnessesEvent', 'Person', 'Flitwick'),
#   ('Person', 'Harry', 'Uses', 'Object', 'Sword'),
#   ('Person', 'Filch', 'Looked for', 'Place', 'somewhere else'),
#   ('Person', 'Dumbledore', 'Looks at', 'Person', 'Lucius Malfoy'),
#   ('Person', 'Black', 'Stares at', 'MagicalCreature', 'Buckbeak'),
#   ('Person', 'Harry', 'Has', 'Object', 'scar'),
#   ('Person', 'Ginny Weasley', 'Not looking at', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Brother of', 'Person', 'George'),
#   ('Person', 'Harry', 'WitnessesEvent', 'Object', 'Whomping Willow'),
#   ('Person', 'Harry', 'Pressed into hands', 'Object', 'Unfogging the Future'),
#   ('Person', 'Harry', 'Student of', 'Person', 'Professor McGonagall'),
#   ('Person', 'Harry', 'Disarms', 'Person', 'Snape'),
#   ('Person', 'Lupin', 'Friendship', 'Person', 'Harry'),
#   ('Object', 'diary', 'Destroyed by basilisk fang', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Friends', 'Person', 'Hermione'),
#   ('Person', 'Aunt Marge', 'FamilyRelation', 'Person', 'Dudley'),
#   ('Person', 'Ron', 'Wearing', 'Object', 'badge'),
#   ('Person', 'Dudley', 'Bullies', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Friendship', 'Person', 'Weasleys'),
#   ('Person', 'Peter Pettigrew', 'Friendship plea', 'Person', 'Ron Weasley'),
#   ('Person', 'Harry', 'Owns', 'Object', 'Wand'),
#   ('Person', 'Snape', 'with Quirrell', 'Person', 'Quirrell'),
#   ('Person', 'Hermione', 'Friend of', 'Person', 'Harry'),
#   ('Person', 'Malfoy', 'Questions', 'Person', 'Harry'),
#   ('Person', 'Professor McGonagall', 'Pushed', 'Person', 'Sir Cadogan'),
#   ('Person', 'Harry', 'Struggles with', 'Person', 'Malfoy'),
#   ('Person', 'Montague', 'Interacts with', 'Person', 'Katie'),
#   ('Person', 'Harry', 'Visits', 'Place', 'Owlery'),
#   ('Place', "Moaning Myrtle's bathroom", 'In', 'Person', 'Harry'),
#   ('Person', 'Ginny Weasley', 'Opens', 'Place', 'Chamber of Secrets'),
#   ('Person', 'Hermione', 'Friendship', 'Person', 'Wood'),
#   ('Person', 'Remus Lupin', 'Defends', 'Person', 'Sirius Black'),
#   ('Person', 'Snape', 'Accusation', 'Person', 'Hermione'),
#   ('Person', 'Tom', 'Acknowledges', 'Person', 'Cornelius Fudge'),
#   ('Person', 'Harry', 'Reads from', 'Object', 'Which Broomstick'),
#   ('Person', 'Fred', 'Takes', 'Object', 'glittering powder'),
#   ('MagicalCreature', 'dementors', 'Affecting', 'Person', 'Harry'),
#   ('Person', 'Hermione', 'Nearer to', 'MagicalCreature', 'Buckbeak'),
#   ('Person', 'Wood', 'Works', 'Object', 'team'),
#   ('Person', 'Harry', 'Sees', 'Object', 'Sign'),
#   ('Person', 'Professor McGonagall', 'Conjures', 'Object', 'Sandwiches'),
#   ('Person', 'Percy', 'Siblings', 'Person', 'Ginny'),
#   ('Person', 'Hermione', 'Possession', 'Object', 'Wand'),
#   ('Person',
#    'Arthur Weasley',
#    'Works at',
#    'Organisation',
#    'Ministry of Magic'),
#   ('Person', 'Ron', 'Owns', 'Object', 'small figure of Viktor Krum'),
#   ('Person', 'Harry', 'Notices', 'Object', 'Piece of paper'),
#   ('Person', 'Professor McGonagall', 'Turns to', 'Person', 'Ron'),
#   ('Place', 'Hogwarts', 'Guide', 'Person', 'Hagrid'),
#   ('Person', 'Sirius Black', 'Godfather of', 'Person', 'Harry'),
#   ('Person', 'Dudley', 'Hits', 'Person', 'father'),
#   ('Person', 'Harry', 'Tries to get', 'Object', 'Stone'),
#   ('Person', 'Arthur Weasley', 'FamilyRelation', 'Person', 'Mrs Weasley'),
#   ('Person', 'Alicia', 'Takes penalty for', 'House', 'Gryffindor'),
#   ('Person', 'Hermione', 'Informs about', 'Person', 'Hagrid'),
#   ('Person', 'Ron', 'Accompanies', 'Person', 'Harry'),
#   ('Person', 'Lockhart', 'Looks at', 'Person', 'Snape'),
#   ('Person', 'Sirius Black', 'Argued with', 'Person', 'Hagrid'),
#   ('Person',
#    'Percy',
#    'Possession',
#    'Object',
#    'small and deeply boring book called Prefects Who Gained Power'),
#   ('Person', 'Hermione', 'Friendship', 'Person', 'Neville'),
#   ('Person', 'Ron', 'Confrontation', 'Person', 'Malfoy'),
#   ('Person', 'Filch', 'Squinted at', 'Person', 'Harry Potter'),
#   ('Person', 'Snape', 'Provoke', 'Person', 'Harry Potter'),
#   ('Person', 'Bertha Jorkins', 'Killed by', 'Person', 'Voldemort'),
#   ('Person',
#    'Fred Weasley',
#    'Knocked off course',
#    'MagicalCreature',
#    'Bludger'),
#   ('Person', 'Harry', 'Finds', 'Object', 'diary'),
#   ('Person', 'Hagrid', 'Hugs', 'Person', 'Harry'),
#   ('Person', 'Lockhart', 'Instructs', 'Person', 'Harry'),
#   ('Person', 'Hermione', 'Studies', 'Object', 'Polyjuice Potion'),
#   ('Person', 'Moaning Myrtle', 'Haunts', 'Place', "Girls' Bathroom"),
#   ('Person', 'Ron', 'Defends', 'Person', 'Hermione'),
#   ('Person', 'Harry', 'Wants back', 'Object', "Riddle's diary"),
#   ('Person',
#    'Salazar Slytherin',
#    'Started',
#    'Miscellaneous',
#    'Pure blood ideology'),
#   ('Person', 'Mrs Weasley', 'Hug', 'Person', 'Harry'),
#   ('Person', 'Parvati', 'Advises', 'Person', 'Harry'),
#   ('Person', 'Harry', 'VictimOfSpell', 'MagicalCreature', 'Dementor'),
#   ('Person', 'Harry', 'Asked', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Looking at', 'Person', 'Ron'),
#   ('Person', 'Justin', 'Carried by', 'Person', 'Professor Sinistra'),
#   ('Person', 'Salazar Slytherin', 'Founder of', 'House', 'Slytherin'),
#   ('Person', 'Harry', 'Friendship', 'Person', 'Sirius'),
#   ('Person', 'Hagrid', 'Opened', 'Object', 'Chamber of Secrets'),
#   ('Person', 'Harry', 'Celebrates with', 'Person', 'George Weasley'),
#   ('Person', 'Harry Potter', 'Heard', 'Person', 'Mr Weasley'),
#   ('Person', 'Snape', 'Calls into fire', 'Person', 'Lupin'),
#   ('Person', 'Hassan Mostafa', 'Releases', 'Object', 'Bludgers'),
#   ('Person', 'Mrs Weasley', 'Possession', 'Object', 'sausages'),
#   ('Person', 'Mr Weasley', 'Father-daughter', 'Person', 'Ginny'),
#   ('Person', 'Aunt Petunia', 'Rivalry', 'Person', 'Harry'),
#   ('Person', 'Hermione', 'Curious about', 'Object', 'Firebolt'),
#   ('Person', 'Lupin', 'Not haunted', 'Place', 'Shrieking Shack'),
#   ('Person', 'Ron', 'Opens presents with', 'Person', 'Harry'),
#   ('Person', 'Malfoy', 'Possesses', 'Object', 'brooms'),
#   ('Person', 'Lupin', 'Possession', 'Object', 'old suitcase'),
#   ('Person', 'Harry', 'Grips', 'MagicalCreature', 'Buckbeak'),
#   ('Person', 'Colin Creevey', 'admires', 'Person', 'Harry'),
#   ('Person', 'Fred Weasley', 'Friendship', 'Person', 'Harry Potter'),
#   ('Person', 'Malfoy', 'Shows to', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Told about past dealings with', 'Person', 'Fudge'),
#   ('Object',
#    'Cauldrons',
#    'Described as',
#    'Object',
#    'Self Stirring Collapsible'),
#   ('MagicalCreature', 'Dobby', 'Points at', 'Object', 'Diary'),
#   ('Person', 'Sirius', 'Provides school things', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Watches', 'Person', 'Neville'),
#   ('Person', 'Fred', 'Removes', 'Object', 'bars'),
#   ('Person', 'George', 'Interacts with', 'MagicalCreature', 'Gnome'),
#   ('Person', 'Ron', 'Advised to', 'Person', 'Harry'),
#   ('Person', 'Hagrid', 'Knows', 'Person', 'Ron'),
#   ('Person', 'Dumbledore', 'UsesMagicOn', 'Person', 'Harry'),
#   ('Person', 'Goyle', 'Acquaintance', 'Person', 'Malfoy'),
#   ('Person', 'Harry', 'yelled', 'Person', 'Knight'),
#   ('Person', 'Harry', 'Chosen', 'House', 'Gryffindor'),
#   ('Person', 'Dumbledore', 'Conversation', 'Person', 'Fudge'),
#   ('Person', 'Harry', 'Visiting', 'Person', 'Hagrid'),
#   ('Person', 'Harry', 'Wearing', 'Object', 'Invisibility Cloak'),
#   ('House', 'Gryffindor', 'WinsEvent', 'Event', 'House championship'),
#   ('Person', 'Ron', 'Wrestled to ground', 'Person', 'Malfoy'),
#   ('Person', 'Harry', 'Found', 'Object', 'Invisibility Cloak'),
#   ('Person', 'Sirius Black', 'Friendship', 'Person', 'Remus Lupin'),
#   ('Person', 'Nearly Headless Nick', 'Friendship', 'Person', 'Sir Patrick'),
#   ('Person', 'Oliver Wood', 'LeadsEvent', 'Event', 'Quidditch match'),
#   ('Person', 'Professor Trelawney', 'Uses', 'Object', 'crystal ball'),
#   ('Person', 'Professor Flitwick', 'Colleague', 'Person', 'Madam Hooch'),
#   ('Person', 'Dumbledore', 'Clicked once', 'Object', 'Silver Put Outer'),
#   ('Person',
#    'Dumbledore',
#    'Welcoming as teacher',
#    'Person',
#    'Professor Lupin'),
#   ('Person', 'Dumbledore', 'Wished good luck', 'Person', 'Harry'),
#   ('Person', 'Madam Hooch', 'Impressed with', 'Object', 'Firebolt'),
#   ('Person', 'George', 'FamilyRelation', 'Person', 'Fred'),
#   ('Person', 'Ron', 'LocatedIn', 'Place', 'Shrieking Shack'),
#   ('Person', 'Peter Pettigrew', 'Owned by Ron', 'Person', 'Ron Weasley'),
#   ('Person', 'Harry', 'Likes that stuff', 'Object', 'Butterbeer'),
#   ('Person', 'Ron', 'Hides in', 'Place', 'wardrobe'),
#   ('Person', 'Ron', 'Thinks about', 'Object', 'black knight'),
#   ('Person', 'Black', 'Witnesses transformation of', 'Person', 'Peter'),
#   ('Person',
#    'Dudley',
#    'Received treatment at',
#    'Place',
#    'private hospital in London'),
#   ('Person', 'Hermione', 'Crossed fingers', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Together', 'Person', 'Hermione'),
#   ('Person', 'Harry', 'PerformsSpell', 'Object', 'broom'),
#   ('Person', 'Hagrid', 'Cheers', 'Person', 'Harry'),
#   ('Person', 'Professor McGonagall', 'Examines', 'Object', 'Firebolt'),
#   ('Person', 'Mr Weasley', 'Concerned behavior', 'Person', 'Dudley'),
#   ('Person', 'Harry', 'Never used', 'Object', 'Floo powder'),
#   ('Person', 'Hagrid', 'Supports', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Friendship', 'Person', 'Ginny'),
#   ('Person', 'Hermione', 'Supports', 'Person', 'Hagrid'),
#   ('Person', 'Professor Lupin', 'Requests to put back', 'Object', 'books'),
#   ('Person', 'Percy', 'Brother of', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Interacts with', 'Person', 'Madam Pomfrey'),
#   ('Person', 'Dudley', 'Calls', 'Person', 'Uncle Vernon'),
#   ('Person', 'Mr Moony', 'WritesDocument', 'Person', 'Professor Snape'),
#   ('Person',
#    'Parvati Patil',
#    'Annoyingly superior looks',
#    'Person',
#    'Lavender Brown'),
#   ('Person', 'Neville', 'in', 'Event', 'Potions lessons'),
#   ('Person', 'Dudley', 'Father-Son', 'Person', 'Uncle Vernon'),
#   ('Person', 'Hermione', 'Watch out for', 'Person', 'Snape'),
#   ('Person', 'Charlie', 'Failed first time', 'Event', 'Apparition Test'),
#   ('Person', 'Uncle Vernon', 'Spouse', 'Person', 'Aunt Petunia'),
#   ('Person', 'Percy', 'FamilyRelation', 'Person', 'Fred'),
#   ('Person', 'Uncle Vernon', 'Visited', 'Person', 'Harry'),
#   ('Person',
#    'Harry',
#    'Communicates with',
#    'MagicalCreature',
#    'Brazilian boa constrictor'),
#   ('Person', 'Hagrid', 'approached', 'Person', 'Ron'),
#   ('Person', 'Harry Potter', 'Disliked by', 'Person', "Dudley's gang"),
#   ('Person', 'People', 'Pointed at', 'Person', 'Harry'),
#   ('Person', 'Hermione', 'Interested in', 'Object', 'Sneakoscope'),
#   ('Person', 'Harry', 'Being mistreated', 'Person', 'Sirius'),
#   ('Person', 'Slytherin', 'CreatorOfObject', 'Object', 'Chamber of Secrets'),
#   ('Person', 'Voldemort', 'FailedToKill', 'Person', 'Harry Potter'),
#   ('Person', 'Harry', 'Interacts with', 'Object', 'Mirror of Erised'),
#   ('Person', 'Neville', 'Possesses', 'Object', 'teacup'),
#   ('Person', 'Harry', 'Receives instruction from', 'Person', 'Hagrid'),
#   ('Person', 'Snape', 'Commenting on', 'Person', 'Professor Lupin'),
#   ('Person', 'Angelina', 'nearly thrown from', 'Person', 'Marcus Flint'),
#   ('Person', 'Harry', 'Said to', 'Person', 'Wood'),
#   ('Person', 'Harry', 'Resemblance to', 'Person', 'James'),
#   ('Person', 'Snape', 'Reprimands', 'Person', 'Hermione'),
#   ('Person', 'Malfoy', 'Friendship', 'Person', 'Crabbe'),
#   ('Person', 'Hedwig', 'Perched on', 'Person', 'Harry'),
#   ('Person', 'Ron', 'LocatedIn', 'Place', "Zonko's"),
#   ('Person', 'Ron', 'Participates in', 'Event', 'Cheering Charms exam'),
#   ('Person', 'Harry', 'Joins', 'Person', 'Ron'),
#   ('Person', 'Hermione', 'Interaction', 'Person', 'Madam Pomfrey'),
#   ('Person', 'Harry', "Parents' best friend", 'Person', 'Sirius'),
#   ('Person', 'Dumbledore', 'Took out', 'Object', 'Silver Put Outer'),
#   ('Person', 'Professor McGonagall', 'LocatedIn', 'Place', 'Great Hall'),
#   ('Person', 'Harry', 'Went down', 'Person', 'Ron'),
#   ('Person', 'Tom Riddle', 'Compares to', 'Person', 'Harry'),
#   ('Person', 'Hermione', 'Saying Myrtle looks nice', 'Person', 'Myrtle'),
#   ('Person', 'Harry', 'WitnessesEvent', 'Person', 'Snape'),
#   ('Person', 'Snape', 'Stopped', 'Person', 'Lupin'),
#   ('Person', 'Ron', 'Friend of', 'Person', 'Harry'),
#   ('Person', 'Black', 'Recognized instantly', 'Person', 'Peter'),
#   ('Person', 'Sir Cadogan', 'Has been', 'Object', 'portrait'),
#   ('Person', 'Harry', 'Confides in', 'Person', 'Hermione'),
#   ('Person', 'Snape', 'Approaches', 'Person', 'Neville'),
#   ('Person', 'Ron', 'Pointing at', 'Person', 'Sir Cadogan'),
#   ('Person', 'Black', 'Cornered', 'Person', 'Peter'),
#   ('Person', 'Dumbledore', 'Beams at Harry', 'Person', 'Harry'),
#   ('Person', 'Neville', 'FamilyRelation', 'Person', 'Grandmother'),
#   ('Person', 'Professor McGonagall', 'Glaring at', 'Person', 'Sir Cadogan'),
#   ('Person', 'Hermione', 'Requests book from', 'Person', 'Lockhart'),
#   ('Person', 'Sirius Black', 'Wants dead', 'Person', 'Harry'),
#   ('Person', 'Ron', 'FamilyRelation', 'Person', 'Ginny'),
#   ('Person', 'Katie Bell', 'Heading for goal', 'Object', 'Quaffle'),
#   ('MagicalCreature', 'Firenze', 'Converses', 'Person', 'Harry Potter'),
#   ('Person', 'Ron', 'Next to', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Mouth falls open at', 'Object', 'food'),
#   ('Person', 'Harry', 'Said to', 'Person', 'Neville'),
#   ('Person', 'Lockhart', 'Possession', 'Object', 'poster'),
#   ('Person', 'Madam Pomfrey', 'Visited', 'Person', 'Harry'),
#   ('Person', 'Lupin', 'Confiscated', 'Object', "Marauder's Map"),
#   ('Person', 'Malfoy', 'PerformsSpell', 'Spell', 'Serpensortial'),
#   ('Person', 'Wood', 'Member of', 'House', 'Gryffindor'),
#   ('Person', 'Ron', 'Rivalry', 'Person', 'Filch'),
#   ('Person', 'Aunt Petunia', 'FamilyRelation', 'Person', 'Harry'),
#   ('Person', 'Oliver Wood', 'Member of', 'House', 'Gryffindor'),
#   ('Person', 'Arthur Weasley', 'Knows', 'Person', 'Ron'),
#   ('Person', 'Harry Potter', 'Related to', 'Person', 'Petunia'),
#   ('Person', 'Wood', 'Mentions playing as Seeker', 'Person', 'Cho Chang'),
#   ('Person', 'Hermione', 'Friendship', 'Person', 'Ron'),
#   ('Person', 'Snape', 'Warns', 'Person', 'Longbottom'),
#   ('Person', 'Colin Creevey', 'Is in', 'Place', 'hospital wing'),
#   ('Person', 'Uncle Vernon', 'Locks up', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Rivalry', 'Person', 'Crabbe'),
#   ('Person', 'Harry', 'Affected by', 'Object', 'Nimbus Two Thousand'),
#   ('Person', 'Hermione', 'Possession', 'MagicalCreature', 'Buckbeak'),
#   ('Person', 'Ron', 'Looks for', 'Person', 'Hermione'),
#   ('Person', 'Ron', 'Friendship', 'Person', 'Neville'),
#   ('Person', 'Tom', 'Acknowledges', 'Person', 'Harry Potter'),
#   ('Person', 'Harry', 'LocatedIn', 'Place', "Mrs Figg's"),
#   ('Person', 'Harry', 'With', 'Person', 'Ron'),
#   ('Person', 'Lupin', 'Revealed secret', 'Person', 'Severus'),
#   ('Person', 'Harry', 'Looks up and down', 'Place', 'Magnolia Crescent'),
#   ('Person', 'Harry', 'Heads down', 'Place', 'entrance hall'),
#   ('Person', 'Professor McGonagall', 'Instructor of', 'Person', 'Harry'),
#   ('Person', 'Fred', 'Steps up to', 'Object', 'glittering powder'),
#   ('Person', 'Harry', 'Leaves with', 'Person', 'Hermione'),
#   ('House', 'Gryffindor', 'Next match against', 'QuidditchTeam', 'Hufflepuff'),
#   ('Person', 'Harry', 'Possesses', 'Object', 'Knuts'),
#   ('Person', 'Mr Roberts', 'Possession', 'Object', 'Map'),
#   ('Person', 'Ron', 'Describes', 'Object', 'sherbet balls'),
#   ('Person', 'Ron Weasley', 'Talks to', 'Person', 'Uncle Vernon'),
#   ('Person', 'Moaning Myrtle', 'Teased about', 'Object', 'Glasses'),
#   ('Person', 'Ron', 'Filled in about', 'Object', 'package'),
#   ('Person', 'Harry', 'Hearing inside walls', 'Object', 'Voice'),
#   ('Person', 'Mrs Weasley', 'FamilyRelation', 'Person', 'Ron'),
#   ('Person', 'Harry Potter', 'Rivalry', 'Person', 'Malfoy'),
#   ('Person', 'Hermione', 'Concerned about', 'Object', 'Firebolt'),
#   ('Person', 'Lupin', 'Untied by', 'Person', 'Black'),
#   ('Person', 'Professor Snape', 'Rivalry', 'Person', 'Professor Quirrell'),
#   ('Person', 'Malfoy', 'Group Change', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Observes', 'Person', 'Draco'),
#   ('Person', 'Madam Rosmerta', 'Knows', 'Person', 'Sirius Black'),
#   ('House', 'Slytherin', 'Won against', 'House', 'Gryffindor'),
#   ('Person', 'Harry', 'Listened to story', 'Person', 'Hagrid'),
#   ('Person', 'Hermione', 'Looked at', 'Object', 'Putrid haggis'),
#   ('Person', 'Harry', 'Wonders about fitting into', 'Object', 'Ford Anglia'),
#   ('Person', 'Harry', 'Versus', 'House', 'Slytherin'),
#   ('Person', 'Professor Lupin', 'Said to', 'Person', 'Neville'),
#   ('Person', 'Madam Hooch', 'Arrives', 'Object', 'broomstick'),
#   ('Person', 'Harry', 'Worked', 'Object', 'Riddle’s diary'),
#   ('Person', 'Snape', 'Teacher of', 'Person', 'Ron'),
#   ('Person', 'Ron', 'Understands', 'Person', 'Hagrid'),
#   ('Person', 'Harry', 'PerformsSpell', 'Spell', 'Expecto Patronum'),
#   ('Person', 'Mrs Dursley', 'Sister of', 'Person', 'Lily'),
#   ('Person', 'Harry', 'Reads', 'Object', 'book'),
#   ('Person',
#    'Professor Trelawney',
#    'Requests teapot',
#    'Person',
#    'Lavender Brown'),
#   ('Person', 'Gilderoy Lockhart', 'Possession', 'Object', 'autobiography'),
#   ('Person', 'Uncle Vernon', 'Boards up', 'Object', 'front and back doors'),
#   ('Object', "Hedwig's cage", 'Contains', 'Person', 'Hedwig'),
#   ('Person', 'Fred Weasley', 'Swinging at', 'MagicalCreature', 'Bludger'),
#   ('Person', 'Lockhart', 'WritesDocument', 'Document', 'autobiography'),
#   ('Person', 'Harry', 'Had Black at his feet', 'Person', 'Black'),
#   ('MagicalCreature', 'Basilisk', 'Threatens', 'Person', 'Harry'),
#   ('Person', 'Ernie Macmillan', 'Supports', 'Person', 'Harry'),
#   ('Person', 'Filch', 'LocatedIn', 'Place', 'Hogwarts'),
#   ('Person', 'Malfoy', 'Mentions dragon to', 'Person', 'Harry Potter'),
#   ('Person', 'Harry', 'Agreeing reluctantly', 'Person', 'Hermione'),
#   ('Person', 'Stan', 'Mistaken Identity', 'Person', 'Harry Potter'),
#   ('Person', 'Harry', 'Told about', 'Object', 'goblet'),
#   ('Person', 'Hagrid', 'Tells', 'Person', 'Hermione'),
#   ('Person', 'Hermione', 'Asking', 'Person', 'Hagrid'),
#   ('Person', 'Hermione', 'Rivalry', 'Person', 'Sirius Black'),
#   ('Person', 'Snape', 'Came in', 'Person', 'Lupin'),
#   ('Person', 'Millicent Bulstrode', 'Belongs to', 'House', 'Slytherin'),
#   ('Person', 'Ron', 'Affected by', 'Event', 'Cheering Charms exam'),
#   ('Person', 'Ron', 'Plans to Curse', 'Person', 'Snape'),
#   ('Person', 'Ron', 'LocatedIn', 'Place', 'Water flood'),
#   ('Person', 'Fred Weasley', 'Friendship', 'Person', 'Hermione Granger'),
#   ('Person', 'Harry', 'FamilyRelation', 'Person', 'Uncle Vernon'),
#   ('Person', 'George', 'Assures', 'Person', 'Harry'),
#   ('Person', 'Malfoy', 'Repeated to', 'Person', 'Harry'),
#   ('Person', 'Lord Voldemort', 'Kills', 'Person', 'Frank Bryce'),
#   ('Person', 'Harry', 'Supports', 'Person', 'Hagrid'),
#   ('Person', 'Madam Hooch', 'says', 'Person', 'Flint'),
#   ('Person', 'Frank', 'BeckonedInsideBy', 'Person', 'Wormtail'),
#   ('Person', 'Harry', 'Participates in', 'Event', 'Potions exam'),
#   ('Person', 'Moaning Myrtle', 'Sitting on', 'Object', 'Toilet'),
#   ('Person', 'Harry', 'TravelTo', 'Place', "Hagrid's Hut"),
#   ('Person', 'Black', 'Ignoring', 'Person', 'Ron'),
#   ('Person', 'Hermione', 'Fear', 'Person', 'Harry'),
#   ('Person', 'Oliver Wood', 'Supports', 'Person', 'Harry Potter'),
#   ('Person', 'Lupin', 'Explains', 'Place', 'Shrieking Shack'),
#   ('Person', 'Harry', 'Living with', 'Person', 'Aunt Petunia'),
#   ('Person', 'Neville Longbottom', 'Awarded points', 'House', 'Gryffindor'),
#   ('Person', 'Professor McGonagall', 'Reprimand', 'Person', 'Mr Potter'),
#   ('Person', 'Crabbe', 'Friendship', 'Person', 'Goyle'),
#   ('Person', 'Harry Potter', 'Encounter', 'Person', 'Tom Riddle'),
#   ('Person', 'Dumbledore', 'Knew about betrayal by', 'Person', 'Sirius Black'),
#   ('Person', 'Professor Quirrell', 'Meets', 'MagicalCreature', 'Hags'),
#   ('Person', 'Harry', 'Possession', 'Object', 'Note'),
#   ('Person', 'Dumbledore', 'Reassures', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Embraces', 'Person', 'Fred'),
#   ('Person', 'Sirius Black', 'Right hand man of', 'Person', 'Voldemort'),
#   ('Person', 'Hagrid', 'Informs', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Attends', 'Event', 'Quidditch World Cup final'),
#   ('Person', 'Malfoy', 'Sneered at', 'Person', 'Hagrid'),
#   ('Person', 'Harry', 'said to', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Asked', 'Person', 'Lupin'),
#   ('Person', 'Mr Crouch', 'been keeping busy', 'Person', 'Bagman'),
#   ('Person', 'Harry', 'Blocked by', 'Person', 'Marcus Flint'),
#   ('Person', 'Dudley', 'Child of', 'Person', 'Aunt Petunia'),
#   ('Person', 'Harry', 'Said', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Interacts with', 'Person', 'Wood'),
#   ('Person', 'Harry', 'Visits', 'Person', 'Hagrid'),
#   ('Person', 'Harry', 'Uses', 'Object', 'roll of parchment'),
#   ('Person', 'George', 'Sibling', 'Person', 'Percy'),
#   ('Person', 'Harry', 'Uses', 'Object', 'Floo powder'),
#   ('Person', 'Harry', 'Addresses', 'Person', 'Mr Malfoy'),
#   ('Person', 'Harry', 'Friend', 'Person', 'Hermione'),
#   ('Person', 'Harry', 'Meets', 'Person', 'Professor Lupin'),
#   ('Person', 'Harry', 'Conversation with', 'Person', 'Wood'),
#   ('Person', 'Harry', 'Concern for', 'Person', 'Ginny'),
#   ('Person', 'Percy Weasley', 'Stopped at', 'Person', 'Ron'),
#   ('Person', 'Hagrid', 'Enchantments', 'Person', 'Professor Snape'),
#   ('Person', 'Percy', 'Meets secretly', 'Person', 'Penelope Clearwater'),
#   ('Person', 'Harry', 'Recipient of letter', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Listens in', 'Place', 'staffroom'),
#   ('Object', 'School robes', 'Owned by', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Possesses', 'Object', "Riddle's diary"),
#   ('Person', 'Harry', 'Hide behind', 'Place', 'Forbidden Forest'),
#   ('Person', 'Hermione', 'Takes out', 'Object', 'Wand'),
#   ('Person', 'Parvati Patil', 'Speaking to Harry', 'Person', 'Lavender Brown'),
#   ('Person', 'Ron', 'Sibling', 'Person', 'Bill'),
#   ('Person', 'Harry', 'Has friends at', 'Organisation', 'Hogwarts'),
#   ('QuidditchTeam',
#    'Gryffindor Quidditch team',
#    'Friendship',
#    'Person',
#    'Fred'),
#   ('Person', 'Harry', 'Receives from', 'Person', 'Sirius'),
#   ('Person', 'Mr Dursley', 'Fear flooded', 'Person', 'Harry Potter'),
#   ('Person', 'Ron', 'HouseAffiliation', 'House', 'Gryffindor'),
#   ('Person', 'Black', 'Identified location of', 'Person', 'Peter'),
#   ('Person', 'Harry', 'Caught sight of', 'Object', 'Mirror'),
#   ('Person', 'Harry', 'moving closer to', 'Person', 'Knight'),
#   ('Person', 'Lupin', 'Watching', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Relation', 'Person', 'Dursleys'),
#   ('Person', 'Harry Potter', 'Tailing closely', 'Person', 'Cho Chang'),
#   ('Person', 'Harry', 'Desiring to improve', 'Spell', 'Patronus'),
#   ('Person', 'Sirius Black', 'Betrayed', 'Person', 'James and Lily Potter'),
#   ('Person', 'Harry', 'TravelTo', 'Place', "King's Cross"),
#   ('Person', 'Harry', 'Said to', 'Person', 'Lucius Malfoy'),
#   ('Person', 'Harry', 'Emerges from', 'Place', 'Flourish and Blotts'),
#   ('Person', 'Harry', 'Supports', 'Person', 'Hermione'),
#   ('Person', 'Hermione', 'Shown', 'Object', 'Diary'),
#   ('Object', 'Nimbus Two Thousand', 'Owned by', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Asked', 'Person', 'Hermione'),
#   ('Person', 'Harry', 'Looking at', 'Person', 'Hermione'),
#   ('Person', 'Harry', 'Encountered', 'Person', 'old man'),
#   ('Person', 'Harry', 'Encounters', 'Person', 'Sirius Black'),
#   ('Person', 'Harry', 'HouseCupLoss', 'House', 'Gryffindor'),
#   ('Person', 'Hagrid', 'Possession', 'Object', 'wand'),
#   ('Person', 'Neville', 'Sprinted out', 'Place', 'hall'),
#   ('Person', 'Harry', 'AskingQuestion', 'Person', 'Hagrid'),
#   ('Person', 'Lupin', 'Teacher-student relationship', 'Person', 'Harry'),
#   ('Person', 'Ron Weasley', 'Belongs to', 'House', 'Gryffindor'),
#   ('Person', 'Ginny Weasley', 'Disturbed by', 'MagicalCreature', 'Mrs Norris'),
#   ('House', 'Slytherin', 'Is', 'Person', 'Bloody Baron'),
#   ('Person', 'Ron', 'Brother of', 'Person', 'Percy'),
#   ('Person', 'Ron', 'Possession', 'MagicalCreature', 'Scabbers'),
#   ('Person', 'Fred', 'Drives', 'Person', 'Harry'),
#   ('Person', 'Ghost', 'Passed through', 'Object', 'Stinking salmon'),
#   ('Person', 'Harry', 'Plays for', 'House', 'Gryffindor'),
#   ('Person', 'Harry', 'Owns', 'Object', 'Broomstick'),
#   ('Person', 'Snape', 'Doubts story', 'Person', 'Dumbledore'),
#   ('Person', 'Harry', 'Guessed that', 'Person', 'Moaning Myrtle'),
#   ('Person', 'Fred and George Weasley', 'Friendship', 'Person', 'Katie'),
#   ('Person', 'Ron', 'Sacrifices for', 'Person', 'Hermione'),
#   ('Person', 'Hermione', 'Affected by', 'Object', 'Portkey'),
#   ('Person', 'Harry Potter', 'Possesses', 'MagicalCreature', 'Hedwig'),
#   ('Person', 'Harry', 'Sticks out leg to trip', 'Person', 'Crabbe'),
#   ('Person', 'Harry', 'Reached', 'Place', 'King’s Cross'),
#   ('Person', 'Ron', 'Points out', 'Person', 'Hermione'),
#   ('Person', 'Ron', 'Snapped', 'Person', 'Malfoy'),
#   ('Person', 'Lupin', 'Supports', 'MagicalCreature', 'Boggart'),
#   ('Person', 'Harry', 'LocatedIn', 'Place', 'Hogwarts'),
#   ('Person', 'Neville', 'WinsEvent', 'House', 'Gryffindor'),
#   ('Person', 'Ron', 'Dragged by', 'Object', 'White queen'),
#   ('Person', 'Hagrid', 'Knows', 'Person', 'Hermione'),
#   ('Person', 'Aunt Petunia', 'Gives', 'Person', 'Harry'),
#   ('Person', 'Fred', 'Said', 'Person', 'George'),
#   ('Person', 'Wood', 'Training harder this year', 'Event', 'Quidditch Cup'),
#   ('Person',
#    'Molly Weasley',
#    'FamilyRelation',
#    'Person',
#    'Fred and George Weasley'),
#   ('Person', 'Harry', 'Encounters', 'Object', 'dog'),
#   ('Person', 'Snape', 'Trying to kill', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Hears', 'Person', 'Lupin'),
#   ('Person', 'Harry', 'Points wand at', 'Person', 'Uncle Vernon'),
#   ('Person', 'Harry', 'Concerned about', 'Person', 'Hippogriff'),
#   ('Person', 'Ron', 'Possesses', 'Object', 'Omnioculars'),
#   ('Person', 'Harry', 'Uses', 'Object', 'ink bottle'),
#   ('Person', 'Harry', 'Mentions', 'Person', 'Snape'),
#   ('Person', 'Mr Weasley', 'Acknowledges presence of', 'Person', 'Mr Malfoy'),
#   ('Person', 'Peeves', 'Encountered by', 'Person', 'Harry'),
#   ('Person', 'Mr Weasley', 'FamilyRelation', 'Person', 'Ron'),
#   ('Person', 'Vulchanov', 'Argument', 'Person', 'Mostafa'),
#   ('Person', 'Hermione', 'Approaches', 'Person', 'Harry'),
#   ('Person', 'Dumbledore', 'Addresses', 'Person', 'Lockhart'),
#   ('Person', 'Harry', 'Receives gift from', 'Person', 'Fred'),
#   ('Person', 'Professor McGonagall', 'Leadership', 'Organisation', 'students'),
#   ('Person', 'Ron', 'Companions', 'Person', 'Hermione'),
#   ('Person', 'Oliver Wood', 'Concerned about', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Travels to', 'Place', 'Forbidden Forest'),
#   ('Person', 'Malfoy', 'Furious about', 'MagicalCreature', 'Buckbeak'),
#   ('Person', 'Ron', 'Avoids detection by', 'Person', 'Snape'),
#   ('Person', 'Hagrid', 'jogging into', 'Place', 'paddock'),
#   ('Person', 'Ern', 'Addresses', 'Person', 'Harry Potter'),
#   ('Person', 'Harry', 'Grabbed', 'Object', 'Cloak'),
#   ('Person', 'Harry', 'said', 'Person', 'Ron'),
#   ('Person', 'Hermione Granger', 'Friendship', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Pulls through', 'Person', 'Ginny'),
#   ('Person', 'Harry', 'What remained of', 'Object', "Riddle's diary"),
#   ('Person', 'Harry', 'Mounts', 'Object', 'Nimbus Two Thousand'),
#   ('Person', 'Ron', 'Rivalry', 'Person', 'Gilderoy Lockhart'),
#   ('Person', 'Draco Malfoy', 'Jealous of', 'Person', 'Harry Potter'),
#   ('Person', 'Harry', 'Supports', 'Person', 'Sirius Black'),
#   ('Person', 'Hagrid', 'Friendship', 'Person', 'Harry'),
#   ('Person', 'Hermione', 'Friendship', 'Person', 'Hagrid'),
#   ('Person', 'Harry', 'Answered', 'Person', 'Ernie'),
#   ('Person', 'Mr Crouch', 'accepts from Percy', 'Object', 'cup'),
#   ('Person', 'Lockhart', 'GivesNoteTo', 'Person', 'Hermione'),
#   ('Person', 'George', 'Dipped hand into', 'Object', 'Floo powder'),
#   ('Person', 'Mrs Weasley', 'Friendship', 'Person', 'Ron'),
#   ('Person', 'Hermione', 'Advises', 'Person', 'Hagrid'),
#   ('Person', 'Tom Riddle', 'Possesses', 'Object', "Harry's wand"),
#   ('Person', 'Fred', 'Flies with', 'Object', 'Car'),
#   ('Person', 'Hagrid', 'approached', 'Person', 'Hermione'),
#   ('Person', 'Harry', 'Needs to see', 'Place', 'Whomping Willow'),
#   ('Person', 'Parvati', 'Explains', 'Person', 'Dean Thomas'),
#   ('Person', 'Sirius', 'Imprisoned in', 'Document', 'Azkaban'),
#   ('Person', 'Ron', 'Possession', 'Object', 'Hermes'),
#   ('Person', 'Hagrid', 'LocatedIn', 'Place', 'Hogwarts'),
#   ('Person', 'Fudge', 'Waits for', 'Person', 'Hagrid'),
#   ('Person', 'Harry', 'Fought', 'MagicalCreature', 'boggart'),
#   ('Person', 'Harry', 'Leaves', 'Person', 'Filch'),
#   ('Person', 'Neville', 'Rivalry', 'Person', 'Malfoy'),
#   ('Person', 'Hagrid', 'Contains', 'Object', 'umbrella'),
#   ('Person', 'Harry', 'WitnessesEvent', 'Person', 'Ron'),
#   ('Person', 'Argus Filch', 'Owner of', 'Object', 'chains and manacles'),
#   ('Person', 'Ron', 'Reads letter from', 'Person', 'Hermione'),
#   ('Person', 'Harry', 'Possession', 'Object', 'wizard coins'),
#   ('Person', 'Harry', 'Talks to', 'Person', 'Ron'),
#   ('Person', 'Lily Potter', 'Sister of', 'Person', 'Petunia Dursley'),
#   ('Person', 'Hagrid', 'Affected by', 'MagicalCreature', 'Dementors'),
#   ('Person', 'Harry', 'Possession', 'Object', 'Firebolt'),
#   ('Person', 'Harry', 'Chases', 'Object', 'something silvery white'),
#   ('Person', 'Hagrid', 'Explains about', 'Object', 'Galleons'),
#   ('Person', 'Dudley', 'Accomplice of', 'Person', 'Piers'),
#   ('Person', 'Harry', 'Friendship', 'Person', 'Fred and George'),
#   ('Person', 'Dumbledore', 'Protects', 'Place', 'Stadium'),
#   ('Person', 'Harry', 'Suggested to stay at', 'Place', 'Leaky Cauldron'),
#   ('Person', 'Harry', 'Moves with', 'Person', 'Hermione'),
#   ('Person', 'Harry', 'Patient', 'Person', 'Madam Pomfrey'),
#   ('Person', 'Seamus Finnigan', 'Cheers', 'Person', 'Harry'),
#   ('House', 'Gryffindor', 'Competing against', 'House', 'Slytherin'),
#   ('Person', 'Snape', 'Reveals location', 'Person', 'Lupin'),
#   ('Person', 'Dean Thomas', 'Friend', 'Person', 'Seamus Finnigan'),
#   ('Person', 'Harry', 'WinsEvent', 'House', 'Gryffindor'),
#   ('Person', 'Lupin', 'Drinks', 'Object', 'Butterbeer'),
#   ('Person', 'Hermione', 'Visits', 'Person', 'Hagrid'),
#   ('Person', 'Hermione Granger', 'Questions', 'Person', 'Severus Snape'),
#   ('Person', 'Hagrid', 'Refers to', 'Person', 'Professor Dumbledore'),
#   ('Person', 'Harry', 'Located in', 'Place', 'Hogwarts'),
#   ('Person', 'Myrtle', 'Said', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Fights with', 'Person', 'Black'),
#   ('Person',
#    'Lockhart',
#    'WritesDocument',
#    'Document',
#    'Wanderings with Werewolves'),
#   ('Person', 'Harry', 'Friendship', 'Person', 'Mr Weasley'),
#   ('Person',
#    'Professor McGonagall',
#    'Announces',
#    'Event',
#    "Dumbledore's Return Announcement"),
#   ('Person', 'Snape', 'Touches', 'Object', 'map'),
#   ('Person', 'Harry', 'Friendship', 'Person', 'Mudbloods'),
#   ('Person', 'Harry', 'Connection', 'Person', 'Hagrid'),
#   ('Person', 'Sirius Black', 'Questioned by', 'Person', 'Dumbledore'),
#   ('Person', 'Harry Potter', 'Promises to', 'MagicalCreature', 'Dobby'),
#   ('Person', 'Harry', "Doesn't want to go back to", 'Place', 'Privet Drive'),
#   ('Person', 'Hermione', 'Painted', 'Object', 'Banner'),
#   ('Person', 'Harry Potter', 'Friendship', 'Person', 'Ron'),
#   ('Person', 'Hagrid', 'Mentions time in', 'Place', 'Azkaban'),
#   ('Object', 'Gringotts vault', 'Possessed by', 'Person', 'Harry'),
#   ('Person', 'Harry Potter', 'Rival of', 'Person', 'Dudley'),
#   ('Person', 'Neville', 'Turned to face', 'Person', 'Malfoy'),
#   ('Person', 'Ron', 'Discussing dragon breeds', 'Object', 'Dragons'),
#   ('Person', 'Voldemort', 'Coming back', 'Person', 'Harry'),
#   ('Person', 'Krum', 'Catches', 'Object', 'Snitch'),
#   ('Person', 'Harry', 'Rivalry', 'Person', 'Voldemort'),
#   ('Person', 'Hagrid', 'Said', 'Person', 'Uncle Vernon'),
#   ('Person', 'Professor McGonagall', 'Summoned', 'Person', 'Harry'),
#   ('Person', 'Parvati', 'Supports', 'Person', 'Lavender'),
#   ('Person', 'Harry', 'Noticing', 'Object', 'Egg'),
#   ('Person', 'Seamus', 'Encounters', 'MagicalCreature', 'Pixies'),
#   ('Person', 'Hagrid', 'Protects', 'Person', 'Narrator'),
#   ('Person', 'Uncle Vernon', 'Annoyed by', 'Person', 'Harry'),
#   ('Person', 'Sirius Black', 'Escaped from', 'MagicalCreature', 'Dementors'),
#   ('Person', 'Ron', 'Comes back with drinks for', 'Person', 'Harry'),
#   ('Person', 'Hermione', 'Hides behind', 'Object', 'Book'),
#   ('Person', 'Ron', 'In front of', 'Object', 'mirror'),
#   ('Person', 'Voldemort', 'Left to die', 'Person', 'Quirrell'),
#   ('Person', 'Mr Weasley', 'Strolls toward', 'Place', 'King’s Cross'),
#   ('Person', 'Ron', 'Jabs at', 'Object', 'Invisibility Booster'),
#   ('Person', 'Professor Snape', 'Scowled at', 'Person', 'Ron'),
#   ('Person', 'Frank', 'Saw lights in', 'Place', 'Riddle House'),
#   ('Person', 'Hagrid', 'talking to', 'Person', 'Crabbe'),
#   ('Person', 'Harry', 'Felt sorry', 'Person', 'Hagrid'),
#   ('Person', 'Voldemort', 'Shows little mercy', 'Person', 'Quirrell'),
#   ('Person',
#    'Professor McGonagall',
#    'Takes possession of',
#    'Object',
#    'Firebolt'),
#   ('Person', 'Harry', 'Possession', 'Object', 'Trunk'),
#   ('Person', 'Harry', 'Grabs', 'Object', 'Invisibility Cloak'),
#   ('Person', 'Ron', 'Supports', 'QuidditchTeam', 'Chudley Cannons'),
#   ('Person', 'Harry', 'Told them where', 'Person', 'Aragog'),
#   ('Person', 'Ron', 'FamilyRelation', 'Person', 'Mr Weasley'),
#   ('Person', 'Harry', 'Currently at', 'Place', 'Privet Drive'),
#   ('Person', 'Harry', 'Touches', 'Object', 'Feathers'),
#   ('Person', 'Wood', 'LocatedIn', 'Place', 'Great Hall'),
#   ('Person', 'Harry', 'Being mistreated by', 'Person', 'Uncle Vernon'),
#   ('Person', 'Ron', 'Talks to Harry', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Noticed', 'Person', 'Snape'),
#   ('Person', 'McGonagall', 'Skeptical of', 'Person', 'Trelawney'),
#   ('Person', 'Lupin', 'Looked suspicious', 'Person', 'Harry'),
#   ('Person', 'Mrs Weasley', 'Gasping', 'Person', 'Harry'),
#   ('Person', 'Weasley twins', 'Tickling', 'MagicalCreature', 'giant squid'),
#   ('Person',
#    'Harry',
#    'Member of',
#    'QuidditchTeam',
#    'Gryffindor Quidditch team'),
#   ('Person', 'Harry', 'Siblings', 'Person', 'Dudley'),
#   ('Person', 'Harry', 'Catches', 'Object', 'Snitch'),
#   ('Person', 'Harry', 'Son of', 'Person', 'Father'),
#   ('Person', 'Voldemort', 'Tried to kill', 'Person', 'Harry'),
#   ('Person', 'Malfoy', 'Provokes', 'Person', 'Harry'),
#   ('Person', 'Hagrid', 'After', 'Person', 'Malfoy'),
#   ('Person', 'Harry', 'Touches', 'Object', 'scar'),
#   ('Person', 'Dumbledore', 'Talking to', 'Person', 'Snape'),
#   ('Person', 'Malfoy', 'Witnesses', 'MagicalCreature', 'dragon'),
#   ('Person', 'Harry', 'Requests', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Gave him', 'Object', 'Sorting Hat'),
#   ('Person', 'Harry', 'Escape', 'Person', 'Pettigrew'),
#   ('Person', 'Wood', 'Talk to', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Reads', 'Document', 'Note'),
#   ('Person', 'Snape', 'Trying to steal', 'Person', 'Flamel'),
#   ('Person', 'Harry', 'Gets swept away with', 'Person', 'Ron'),
#   ('Person', 'Ron', 'Seeks advice from', 'Person', 'Lockhart'),
#   ('Person', 'Hagrid', 'Partners with', 'Person', 'Harry'),
#   ('Person', 'Malfoy', 'Cheats against', 'Person', 'Harry'),
#   ('Person', 'Mr Weasley', 'Possession', 'Object', 'car'),
#   ('Object', 'Wardrobe', 'Contains', 'MagicalCreature', 'Boggart'),
#   ('Person', 'Professor Trelawney', 'MovesOver', 'Person', 'Parvati'),
#   ('Person', 'Hagrid', 'Angry', 'Person', 'Harry'),
#   ('Person', 'Hermione', 'Mentions as haunted', 'Place', 'Shrieking Shack'),
#   ('Person', 'Harry', 'Nephew of', 'Person', 'Uncle Vernon'),
#   ('Person', 'Dumbledore', 'Wants to speak', 'Person', 'Harry'),
#   ('Person', 'Percy', 'Calls for', 'Person', 'Dumbledore'),
#   ('Person', 'Harry', 'Staring through', 'Object', 'Omnioculars'),
#   ('Person', 'Ron', 'Approaches', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Friendship', 'Person', 'Harry Potter'),
#   ('Object', 'engine', 'Exhibits behavior', 'Object', 'groaning'),
#   ('Person', 'Bloody Baron', 'Given wide berth', 'Person', 'Other Ghosts'),
#   ('Person', 'Ginny Weasley', 'Confides in', 'Person', 'Tom Riddle'),
#   ('Person', 'Hagrid', 'Owns', 'MagicalCreature', 'Buckbeak'),
#   ('Person', 'Hagrid', 'Gave furious look', 'Person', 'Dursley'),
#   ('Person', 'Hagrid', "Didn't want to tell", 'Person', 'Harry'),
#   ('Person', 'Harry', 'Receives', 'Document', 'Letter'),
#   ('Person', 'Hermione', 'HasSpellEffect', 'Person', 'Snape'),
#   ('Person', 'Harry', 'Anxious look', 'Person', 'Ginny'),
#   ('Person', 'Oliver Wood', 'Friendship', 'Person', 'Harry Potter'),
#   ('Person', 'Percy', 'Friendship', 'Person', 'Harry'),
#   ('Person',
#    'Severus Snape',
#    'Threatens with Dementors',
#    'Person',
#    'Sirius Black'),
#   ('Person', 'Oliver Wood', 'Member of', 'Organisation', 'Puddlemere United'),
#   ('Person', 'Hagrid', 'Mentioned', 'Person', 'Professor Lupin'),
#   ('Person', 'Harry', 'Asks about creatures', 'Person', 'Hagrid'),
#   ('Person', 'Harry', 'Interacted with', 'Person', 'Dumbledore'),
#   ('Person', 'Harry', 'said to', 'Person', 'Hermione'),
#   ('Person', 'George', 'Compliments', 'Person', 'Harry'),
#   ('Person', 'Dumbledore', 'Warned', 'Person', 'James Potter'),
#   ('Person', 'Volkov', 'Argument', 'Person', 'Mostafa'),
#   ('Person', 'George', 'Stopping', 'MagicalCreature', 'Bludger'),
#   ('Person', 'Hermione', 'Touches', 'Object', 'Portkey'),
#   ('Person', 'Wood', 'LeadsEvent', 'QuidditchTeam', 'team'),
#   ('Person', 'Snape', 'Discovers map', 'Person', 'Lupin'),
#   ('Person', 'Frank', 'Mentions', 'Place', 'Ministry of Magic'),
#   ('Person', 'Harry', 'AsksAbout', 'Person', 'Lupin'),
#   ('Person', 'Ron', 'Shakes', 'Object', 'steering wheel'),
#   ('Person', 'Harry Potter', 'Has', 'Object', 'Sorting Hat'),
#   ('Person', 'Harry', 'Silently through the trees', 'Place', "Hagrid's house"),
#   ('House',
#    'Gryffindor',
#    'Received applause from Ravenclaw',
#    'House',
#    'Ravenclaw'),
#   ('Person', 'Ron', 'Looking at', 'Person', 'Harry'),
#   ('Person', 'Mr Weasley', 'Pays with', 'Object', 'Muggle money'),
#   ('Person', 'Aunt Marge', 'Possession', 'Person', 'Ripper'),
#   ('Person', 'Fred', 'Slip in', 'Object', 'dragon dung'),
#   ('Person', 'Mr Weasley', 'Embarrassed by', 'Person', 'Mr Malfoy'),
#   ('Person', 'Lockhart', 'Puts Memory Charm', 'Spell', 'Memory Charm'),
#   ('Person', 'Harry', 'Interacts with', 'Person', 'Stan'),
#   ('Person', 'Professor McGonagall', 'Teacher of', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Broom malfunction', 'Object', 'Nimbus Two Thousand'),
#   ('Person',
#    'Hermione',
#    'Arrives at',
#    'Place',
#    "Professor Trelawney's classroom"),
#   ('Person', 'Harry', 'Interacts with', 'MagicalCreature', 'Gnome'),
#   ('Person', 'Harry', 'Wondering', 'Person', 'Snape'),
#   ('Person', 'Ginny Weasley', 'Sits next to', 'Person', 'Ron'),
#   ('Person', 'Irish Beater Quigley', 'Hits Bludger', 'Person', 'Krum'),
#   ('Person', 'Harry Potter', 'Belongs to', 'House', 'Gryffindor'),
#   ('Person', 'Ron', 'Visits', 'Person', 'Hermione'),
#   ('Person', 'Lupin', 'Watching', 'Person', 'Hermione'),
#   ('Person', 'Quirrell', 'Serves', 'Person', 'Voldemort'),
#   ('Person', 'Ron', 'Snatched', 'Object', 'Letter'),
#   ('Person', 'Harry', 'Connection with', 'Person', 'Pettigrew'),
#   ('Person', 'Malfoy', 'Loses possession of', 'Object', "Riddle's diary"),
#   ('Person', 'Hermione', 'Attends', 'Event', 'Divination class'),
#   ('Person', 'Hagrid', 'Gifts', 'Object', 'owl'),
#   ('Person', 'Frank', 'Picked up', 'Object', 'walking stick'),
#   ('Person',
#    'Dumbledore',
#    'Equals in power',
#    'Person',
#    'He Who Must Not Be Named'),
#   ('Person', 'Ron', 'Suspects', 'Person', 'Malfoy'),
#   ('Person',
#    'Peeves the Poltergeist',
#    'Affected by spell',
#    'Person',
#    'Professor Lupin'),
#   ('Person', 'Harry', 'WitnessesEvent', 'MagicalCreature', 'Veela'),
#   ('Person',
#    'Oliver Wood',
#    'ParticipatesInEvent',
#    'QuidditchTeam',
#    'Gryffindor'),
#   ('Person', 'Harry', 'Friends with', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Accompanied by', 'MagicalCreature', 'Fang'),
#   ('Person', 'Oliver Wood', 'Discusses', 'Object', 'Firebolt'),
#   ('Person', 'Aunt Petunia', 'Possession', 'Object', 'cushions'),
#   ('Person', 'Ron', 'Compares', 'Person', 'Percy'),
#   ('Person', 'Ron', 'Looks at', 'Person', 'Professor McGonagall'),
#   ('Person', 'Hermione', 'Needs', 'Object', 'library'),
#   ('Person', 'Lucius Malfoy', 'Threatened by', 'MagicalCreature', 'Dobby'),
#   ('Person', 'Mr Roberts', 'Parent of', 'Person', 'Muggle child'),
#   ('Person', 'Harry', 'Owns', 'Object', 'Money bag'),
#   ('Person', 'Ron', 'Wants to get checked', 'Object', 'Scabbers'),
#   ('Person', 'Mr Weasley', 'Possession', 'Object', 'tents'),
#   ('Person', 'Harry', 'Scar pain', 'Person', 'Voldemort'),
#   ('Person', 'Professor Binns', 'LocatedIn', 'Place', 'Hogwarts'),
#   ('Person', 'Hermione', 'Doubt', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Descendant of', 'Person', 'Father'),
#   ('Person', 'Harry', 'Fear', 'Person', 'Voldemort'),
#   ('Person', 'Lupin', 'Tries to explain', 'Person', 'Harry'),
#   ('MagicalCreature', 'Firenze', 'Helps', 'Person', 'Harry Potter'),
#   ('Person', 'Harry', 'ParticipatesInEvent', 'Event', 'Quidditch practice'),
#   ('Person',
#    'Professor Sprout',
#    'Colleague',
#    'Person',
#    'Professor McGonagall'),
#   ('Person', 'Harry', 'Possible identity', 'Person', "Harry's dad"),
#   ('Person', 'Lockhart', 'Possession', 'Object', 'wand'),
#   ('Person', 'Ron', 'Asks questions', 'Person', 'Ginny'),
#   ('Person', 'Harry', 'Leaves through', 'Place', 'Gryffindor common room'),
#   ('Person', 'Riddle', 'Turn in', 'Person', 'Rubeus'),
#   ('Person', 'Ron', 'Displeasure', 'Person', 'Harry'),
#   ('Person', 'Mr Dursley', 'Mentioned name', 'Person', 'Harry Potter'),
#   ('Person', 'Ron', 'Explains', 'Object', 'Chocolate Frogs'),
#   ('Person', 'Percy Weasley', 'Watching', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Said George', 'Person', 'George'),
#   ('Person', 'Harry Potter', 'Resemble', 'Person', 'James Potter'),
#   ('Person',
#    'Arthur',
#    'Connections at',
#    'Organisation',
#    'Department of Magical Games and Sports'),
#   ('Person', 'Hagrid', 'Asks about', 'MagicalCreature', 'Ronan'),
#   ('Person', 'Harry Potter', 'Comparison', 'Person', 'Everyone else'),
#   ('Place', 'Hogwarts Express', 'Travels to', 'Place', 'Hogwarts'),
#   ('Person', 'Hagrid', 'Said about', 'Place', 'Gringotts'),
#   ('Person', 'Hermione', 'VictimOfSpell', 'Person', 'Sirius Black'),
#   ('Person', 'Harry', 'WitnessesEvent', 'Person', 'Hagrid'),
#   ('Person', 'Harry', 'gaining on', 'Person', 'Malfoy'),
#   ('Person', 'Peter Pettigrew', 'Fear', 'Person', 'Voldemort'),
#   ('Person', 'Mr Malfoy', 'Rounds on', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Confronts', 'Person', 'Riddle'),
#   ('Person', 'Tom Riddle', 'Met', 'Person', 'Harry'),
#   ('Person', 'Neville', 'Possession', 'Object', 'Trevor'),
#   ('Person', 'Harry', 'Interacted with', 'Person', 'Madam Malkin'),
#   ('Person', 'Harry', 'Attends lesson', 'Person', 'Professor McGonagall'),
#   ('Person', 'Fred and George Weasley', 'Friendship', 'Person', 'Angelina'),
#   ('Person', 'Harry', 'Travels together', 'Person', 'Hermione'),
#   ('Person', 'Harry', 'Said quietly to', 'Person', 'Malfoy'),
#   ('Person', 'Mr Weasley', 'FamilyRelation', 'Person', 'George'),
#   ('Person', 'Ron', 'Possession', 'Object', 'Sweets'),
#   ('Person', 'McGonagall', 'Doubts capabilities', 'Person', 'Hagrid'),
#   ('Person', 'Harry', 'Pointed out', 'Person', 'Ron'),
#   ('Person', 'Rowena Ravenclaw', 'FounderOf', 'Place', 'Hogwarts'),
#   ('Person', 'Snape', 'Held', 'Object', 'Cloak'),
#   ('Person', 'Professor Lupin', 'Teaches', 'Person', 'Harry'),
#   ('Person', 'Malfoy', 'Curious about', 'Person', 'Harry'),
#   ('Person', 'Filch', 'Knows secret passageways', 'Place', 'school'),
#   ('Person', 'Harry', 'Noticing', 'Person', 'Cho Chang'),
#   ('Person', 'Ginny', 'Needs', 'Object', 'robes'),
#   ('Person',
#    'Harry',
#    'Getting onto',
#    'Place',
#    'platform nine and three quarters'),
#   ('MagicalCreature', 'Dobby', 'Friendship', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Releases', 'Object', 'Snitch'),
# ...
#   ('Person', 'Seamus', 'Helped himself', 'Person', 'Harry'),
#   ('Person',
#    'Nearly Headless Nick',
#    'Received letter from',
#    'Person',
#    'Sir Patrick Delaney Podmore'),
#   ('MagicalCreature', 'Dobby', 'Hits', 'Person', 'Mr Malfoy'),
#   ('Person', 'Ernie', 'Saw Harry chasing the snake', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Possession', 'Object', 'Filibuster Fireworks'),
#   ('Person', 'Lupin', 'Teaches about Patronus', 'Person', 'Harry'),
#   ('Person', 'Hermione', 'Interrupting Snape', 'Person', 'Snape'),
#   ('Person', 'George', 'Hits', 'Person', 'Harry'),
#   ('Person', 'Fred', 'Friendship', 'Person', 'Wood'),
#   ('Person', 'Professor McGonagall', 'Asking about health', 'Person', 'Harry'),
#   ('Person', 'George', 'Challenged', 'Person', 'Ron'),
#   ('Person',
#    'Cedric Diggory',
#    'Seeker of',
#    'QuidditchTeam',
#    'Hufflepuff House Quidditch team'),
#   ('Person', 'Harry', 'Locked away', 'Object', 'broomstick'),
#   ('Person', 'Dumbledore', 'Talking to', 'Person', 'Percy'),
#   ('Person', 'Harry', 'Enemy of', 'Person', 'Voldemort'),
#   ('Person', 'Johnson', 'Takes', 'Object', 'Quaffle'),
#   ('Person', 'Hermione', 'Flattering', 'Person', 'Hagrid'),
#   ('Person', 'Hermione', 'Moves closer', 'Person', 'Ron'),
#   ('Person', 'Malfoy', 'Friends', 'Person', 'Goyle'),
#   ('Person', 'Ron', 'Accusing of', 'Person', 'Percy'),
#   ('Person', 'Harry', 'Talked to', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Keeps folded', 'Object', 'Invisibility Cloak'),
#   ('Person', 'Mr Weasley', 'FamilyRelation', 'Person', 'Ginny'),
#   ('Person',
#    'Sir Patrick',
#    'ParticipatesInEvent',
#    'Event',
#    'Head Hockey game'),
#   ('Person', 'Katie', 'Drops', 'Object', 'Quaffle'),
#   ('Person', 'Percy', 'Join', 'Person', 'Harry'),
#   ('Person', 'Hermione', 'PerformsSpell', 'Spell', 'Wingardium Leviosa'),
#   ('Person', 'boy', 'Expresses disdain towards', 'Person', 'Harry'),
#   ('Person', 'Harry Potter', 'Caused scar', 'Person', 'Voldemort'),
#   ('Person', 'Frank', 'Mentions', 'Person', 'Harry Potter'),
#   ('Person', 'Harry', 'Friends', 'Person', 'Ron'),
#   ('Person', 'Dumbledore', 'Not happy with', 'Person', 'Mr Weasley'),
#   ('Person', 'Bole', 'Attacked the Keeper', 'Person', 'Wood'),
#   ('Object', 'Invisibility Cloak', 'Under', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Annoys', 'MagicalCreature', 'Errol'),
#   ('Person', 'George', 'Father', 'Person', 'Mr Weasley'),
#   ('Person', 'Harry', 'Respected', 'Person', 'Dumbledore'),
#   ('Person', 'Harry Potter', 'Friendship', 'Person', 'Dobby'),
#   ('Person', 'Snape', 'Rivalry', 'Person', 'Seamus'),
#   ('Person', 'Angelina', 'Giggles about', 'Person', 'Cedric Diggory'),
#   ('Person', 'Lee Jordan', 'Comments on', 'House', 'Slytherin'),
#   ('Person', 'Hermione', 'Covers face', 'Person', 'Harry'),
#   ('Person', 'Vulchanov', 'ParticipatesInEvent', 'Person', 'Volkov'),
#   ('Person', 'Dumbledore', 'Mentions', 'Person', 'Harry'),
#   ('Person', 'Cho', 'Friendship', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Belongs to', 'House', 'Gryffindor'),
#   ('Person', 'Dumbledore', 'Gamekeeper back', 'Organisation', 'Azkaban'),
#   ('Person', 'Snape', 'Conjuring stretchers', 'Person', 'Hermione'),
#   ('Person', 'Mr Weasley', 'Comments on', 'Object', 'Program'),
#   ('Person', 'Pansy Parkinson', 'Runs up', 'Place', 'marble staircase'),
#   ('Person', 'Draco', 'Rivalry', 'Person', 'Harry'),
#   ('Person', 'Percy', 'Tells', 'Person', 'Fred'),
#   ('Person', 'Harry Potter', 'Asked about scar', 'Person', 'Fred Weasley'),
#   ('Person', 'Malfoy', 'Wants revenge on', 'Person', 'Black'),
#   ('Person', 'Hagrid', 'Surprises', 'Person', 'Tom Riddle'),
#   ('Person', 'Winky', 'Made to trample tents', 'Person', 'Mr Crouch'),
#   ('Person', 'Remus Lupin', 'Friendship', 'Person', 'Peter Pettigrew'),
#   ('Person', 'Professor Flitwick', 'Puts into', 'Person', 'class'),
#   ('Person', 'Lee Jordan', 'Friend of', 'Friendship', 'Weasley twins'),
#   ('Person', 'Ludo', 'PerformsSpell', 'Spell', 'Sonorus'),
#   ('Person', 'Harry', 'Watching', 'Person', 'Crabbe'),
#   ('Person', 'Fred', 'Challenged', 'Person', 'Harry'),
#   ('Person', 'Draco', 'Strutting around', 'Place', 'school'),
#   ('Person', 'Filch', 'LocatedIn', 'Place', 'Corridor'),
#   ('Person', 'Ron', 'Looks sideways', 'Person', 'Hermione'),
#   ('Person', 'Malfoy', 'Shows to', 'Person', 'Crabbe'),
#   ('Person', 'Harry', 'Located at', 'Place', 'Leaky Cauldron'),
#   ('Person', 'Harry', 'Belongs to', 'Place', 'Gryffindor Tower'),
#   ('Person', 'Ron', 'Interaction', 'Person', 'Madam Pince'),
#   ('Person', 'Vernon', 'Spouse of', 'Person', 'Mrs Mason'),
#   ('Object', 'diary', 'Fell into lap', 'Person', 'Harry'),
#   ('Person', 'Dumbledore', 'Appoints', 'Person', 'Lupin'),
#   ('Person', 'Dobby', 'Tells', 'Person', 'Harry'),
#   ('Person', 'Ginny', 'Friendship', 'Person', 'Hermione'),
#   ('Person', 'Harry', 'Desired', 'Object', 'solid gold cauldron'),
#   ('Person', 'Neville Longbottom', 'Assists', 'Person', 'Professor Lupin'),
#   ('Person', 'Fred Weasley', 'Interacts with', 'Person', 'Harry'),
#   ('Person', 'Mrs Weasley', 'Marriage', 'Person', 'Mr Weasley'),
#   ('Person', 'Harry Potter', 'Protect', 'Person', 'Sirius Black'),
#   ('Person', 'Dumbledore', 'Leadership', 'Person', 'Argus Filch'),
#   ('Person', 'Harry', 'Casts', 'Spell', 'Expelliarmus'),
#   ('Person',
#    'Dumbledore',
#    'Business with',
#    'Organisation',
#    'Ministry of Magic'),
#   ('Person', 'Malfoy', 'Getting comeuppance', 'Event', 'Comeuppance'),
#   ('Person', 'Mr Weasley', 'Peels apart', 'Object', 'Muggle money'),
#   ('Person', 'Troy', 'Zoom closely together', 'Person', 'Mullet'),
#   ('Person', 'Harry', 'Strange silver', 'Object', 'Instruments'),
#   ('Person',
#    'Gilbert Wimple',
#    'MemberOf',
#    'Organisation',
#    'Committee on Experimental Charms'),
#   ('Person', 'Harry', 'Rivalry', 'Person', 'Snape'),
#   ('Person', 'Hermione', 'Friendship', 'Person', 'McGonagall'),
#   ('Person', 'Madam Hooch', 'Whistle rang out', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Has eyes', 'Person', 'Mom'),
#   ('Person',
#    'Mr Weasley',
#    'LocatedIn',
#    'Place',
#    'Quidditch World Cup campsite'),
#   ('Person', 'Filch', 'LocatedAt', 'Object', 'door'),
#   ('Person', 'Harry', 'Compares with', 'Object', 'Nimbus Two Thousand'),
#   ('Person', 'Black', 'Met', 'Person', 'Fudge'),
#   ('Object', 'wand', 'Falls to floor', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Friendship', 'Person', 'Hagrid'),
#   ('Person', 'Ginny', 'Asks', 'Person', 'Dumbledore'),
#   ('Person', 'Harry', 'Muttered to', 'Person', 'Ron'),
#   ('Person', 'Black', 'wand pointing at', 'Person', 'Harry'),
#   ('Person', 'Harry', 'LocatedIn', 'Place', "Mrs Norris' spot"),
#   ('Person', 'Sirius Black', 'Rivalry', 'Person', 'Azkaban guards'),
#   ('Person', 'James', 'Used by', 'Object', 'Invisibility Cloak'),
#   ('Person', 'Sorting Hat', 'Wanted to put', 'Person', 'Harry'),
#   ('Person', 'Hagrid', 'Owner of', 'MagicalCreature', 'Aragog'),
#   ('Person', 'Harry', 'Gets out of', 'Object', 'Invisibility Cloak'),
#   ('Person', 'Dumbledore', 'Leadership', 'Person', 'Hermione'),
#   ('Person', 'Ron', 'Next to the', 'Object', 'cage of his fellow rats'),
#   ('Person', 'Lupin', 'Frowning slightly', 'Person', 'Harry'),
#   ('Person', 'Harry', 'voice shaking slightly', 'Person', 'Black'),
#   ('Person', 'Ron', 'Possession', 'Object', "Harry's robes"),
#   ('Person', 'Harry', 'Locked away', 'Object', 'spellbooks'),
#   ('Person', 'Harry', 'Observes', 'Person', 'Percy'),
#   ('Person', 'Percy Weasley', 'Needed top grades for', 'Event', 'N.E.W.T.s'),
#   ('Person', 'Peter Pettigrew', 'Friendship', 'Person', 'Sirius Black'),
#   ('Person', 'Harry', 'Holds', 'Person', 'Hermione'),
#   ('Person', 'Uncle Vernon', 'Is angry at', 'Person', 'Harry'),
#   ('Person', 'Alicia', 'Voices', 'Person', 'Harry'),
#   ('MagicalCreature',
#    'fat white rabbit',
#    'Changing into',
#    'Object',
#    'silk top hat'),
#   ('Person', 'Mr Weasley', 'Keeps close to', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Target of', 'Person', 'Lord Voldemort'),
#   ('Person', 'Harry', 'Victim of Spell', 'MagicalCreature', 'Basilisk'),
#   ('Person', 'Mr Weasley', 'Colleague', 'Person', 'Basil'),
#   ('Person', 'Harry', 'Thinks about', 'Person', 'Malfoy'),
#   ('Organisation',
#    'Department of Magical Games and Sports',
#    'Supports',
#    'Person',
#    'Ludo Bagman'),
#   ('Person', 'Ron', 'Friendship', 'Person', 'George'),
#   ('Person', 'Hermione', 'Located in', 'Place', 'Great Hall'),
#   ('Person', 'Ron', 'Friendship', 'Person', 'Hermione'),
#   ('Person', 'Harry', 'Part of game plan', 'Person', 'Wood'),
#   ('Object', 'Sorting Hat', 'Gathers', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Possesses', 'Object', 'Wand'),
#   ('Person', 'Fred and George', 'Possession', 'Object', 'flying car'),
#   ('Person', 'Mr Weasley', 'Strolls toward', 'Person', 'Harry'),
#   ('Person', 'Harry', 'Partners in', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Fighting against', 'Person', 'Lord Voldemort'),
#   ('Person', 'Hermione', 'HouseAffiliation', 'House', 'Gryffindor'),
#   ('Person', 'Fred Weasley', 'Pelted Bludger at', 'Person', 'Warrington'),
#   ('Person', 'Neville', 'Friendship', 'Person', 'Harry'),
#   ('Person', 'Lockhart', 'PerformsSpell', 'Spell', 'Serpensortial'),
#   ('Person', 'Hagrid', 'Follows', 'MagicalCreature', 'Spiders'),
#   ('Person', 'Hagrid', 'Supports', 'MagicalCreature', 'Fang'),
#   ('Person', 'Ron', 'Fixates on', 'Person', 'Harry'),
#   ('Person', 'Professor Lupin', 'Contains', 'Object', 'Wardrobe'),
#   ('Person', 'Dean Thomas', 'Snapped at', 'Person', 'Malfoy'),
#   ('Person', 'Hermione', 'Whispered', 'Person', 'Ron'),
#   ('Person', 'Hannah Abbott', 'From', 'House', 'Hufflepuff'),
#   ('Person', 'Harry', 'Expectation', 'Person', 'Snape'),
#   ('Person', 'Hermione', 'Looks for', 'Object', 'milk jug'),
#   ('Person', 'Hagrid', 'Betrays', 'Person', 'Lockhart'),
#   ('Person', 'Oliver Wood', 'Talks to', 'Person', 'Flint'),
#   ('Person', 'Seamus', 'Asked about Neville', 'Person', 'Ron'),
#   ('Person', 'Ludo Bagman', 'Recognition', 'Person', 'Harry Potter'),
#   ('Person', 'Fudge', 'Consulted by', 'Person', 'Dumbledore'),
#   ('Person', 'Harry', 'Friendship', 'Person', 'Flitwick'),
#   ('Person', 'Professor McGonagall', 'Reading', 'Document', 'parchment'),
#   ('Person',
#    'Mr Weasley',
#    'embargo on flying carpets',
#    'Person',
#    'Ali Bashir'),
#   ('Person', 'Fred Weasley', 'Competes with', 'Person', 'Malfoy'),
#   ('Person', 'Dumbledore', 'Mentorship', 'Person', 'Harry'),
#   ('Person', 'Lee', 'Shows', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Says', 'Person', 'Harry'),
#   ('Person', 'Ginny Weasley', 'WitnessesEvent', 'Person', 'Dumbledore'),
#   ('Person', 'Harry', 'Encountered', 'Person', 'Voldemort'),
#   ('Person', 'Harry Potter', 'Turns off', 'Object', 'Alarm Clock'),
#   ('Person', 'Harry', 'Friendship', 'Person', 'Fred'),
#   ('Person', 'Harry', "Hasn't got past", 'Person', 'Sirius Black'),
#   ('Person', 'Goblin', 'Wearing', 'Object', 'Uniform'),
#   ('Person', 'Dumbledore', 'Colleague of', 'Person', 'McGonagall'),
#   ('Person', 'Harry', 'Next to', 'Person', 'Ron'),
#   ('Person', 'Albus Dumbledore', 'Defeat of', 'Person', 'Grindelwald'),
#   ('Person', 'George', 'Friendship', 'Person', 'Harry'),
#   ('Person', 'Winky', 'Forced to go up', 'Person', 'Mr Crouch'),
#   ('Person', 'Ron', 'ImaginesLivingIn', 'Place', 'Forbidden Forest'),
#   ('Person',
#    'Mr Weasley',
#    'Looks up to',
#    'Place',
#    'platform nine and three quarters'),
#   ('Person',
#    'Harry',
#    'ParticipatesInEvent',
#    'Event',
#    'Transfiguration Lesson'),
#   ('Person', 'Hermione', 'Helps', 'Person', 'Neville'),
#   ('Person', 'Harry', 'Seeks', 'Object', 'Golden Snitch'),
#   ('Person', 'Crookshanks', 'Chews in front of', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Friends', 'Person', 'Hermione'),
#   ('Person', 'Harry', 'Noticed', 'Object', 'Key'),
#   ('Person', 'Fudge', 'Sends cars to', 'Person', 'Harry'),
#   ('Person', 'Fred Weasley', 'Helps Gryffindor', 'Person', 'Harry'),
#   ('Person', 'Hagrid', 'Friendship', 'Person', 'Flitwick'),
#   ('Person', 'Hagrid', 'Enchantments', 'Person', 'Professor Flitwick'),
#   ('Person', 'Lupin', 'Had', 'Document', "Marauder's Map"),
#   ('Person', 'Harry', 'Partners with', 'Person', 'Seamus Finnigan'),
#   ('Person', 'Harry', 'Looks at watch', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Ties', 'Object', 'bars'),
#   ('Person', 'Uncle Vernon', 'Possesses', 'Object', 'trunk'),
#   ('Person', 'Ron', 'Friendship', 'Person', 'Flamel'),
#   ('Person', 'Mr Weasley', 'Called to look', 'Person', 'Harry'),
#   ('Person',
#    'Harry',
#    'Seeker recommended by',
#    'Person',
#    'Professor McGonagall'),
#   ('Person', 'Harry', 'Classmates', 'Person', 'Neville'),
#   ('Person', 'Hagrid', 'Takes down to', 'Place', 'Hogwarts'),
#   ('Person', 'Filch', 'UnderCurse', 'Miscellaneous', 'Squib'),
#   ('Person', 'Flitwick', 'Friendship', 'Person', 'McGonagall'),
#   ('Person', 'Woman', 'Waves at', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Said', 'Person', 'Harry Potter'),
#   ('Person', 'Lockhart', 'PerformsSpell', 'Spell', 'Disarming Charm'),
#   ('Person', 'Lucius Malfoy', 'Sacked from', 'Organisation', 'Hogwarts'),
#   ('Person', 'Ron', 'Out of his', 'Object', 'inside pocket'),
#   ('Person', 'Dumbledore', 'Presents', 'Object', 'Quidditch Cup'),
#   ('Person', 'Lupin', 'Friendship', 'Person', 'Ron'),
#   ('Person', 'Harry', 'Uses', 'Object', 'lamp'),
#   ('Person', 'Flitwick', 'Decorates', 'Object', 'classroom'),
#   ('Person', 'Fred Weasley', 'Supports', 'Person', 'George Weasley'),
#   ('Person', 'Harry', 'Stuffs back into', 'Object', 'wand'),
#   ('Person', 'Snape', 'gave Harry', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Furious moves', 'Person', 'Malfoy'),
#   ('Person', 'Ron', 'Covered in', 'Object', 'cloak'),
#   ('Person', 'Black', 'Snarls at', 'Person', 'Harry'),
#   ('Person', 'Madam Pince', 'Interacts with', 'Person', 'Harry'),
#   ('Person', 'Harry', 'TravelTo', 'Place', 'forest'),
#   ('Person', 'Ron Weasley', 'Consults', 'Person', 'Mr. Weasley'),
#   ('Object', 'cats', 'Of every color', 'Miscellaneous', 'every color'),
#   ('Person', 'Ginny', 'Sibling of', 'Person', 'Harry'),
#   ('Person', 'Fluffy', 'Alive', 'Person', 'Voldemort'),
#   ('Person', 'Harry', 'Drank tea', 'Person', 'Lupin'),
#   ('Person', 'Harry', 'Mentions', 'Place', 'Hogsmeade'),
#   ('Person', 'Harry', 'Rides', 'Object', 'Firebolt'),
#   ('Person', 'Ginny', 'Supports', 'MagicalCreature', 'Pigwidgeon'),
#   ('Person', 'Fred', 'Sibling', 'Person', 'George'),
#   ('Person', 'Mr Weasley', 'Asks about trunk', 'Person', 'Harry'),
#   ('Person', 'Aragog', 'Given to', 'Person', 'Hagrid'),
#   ('Person', 'Tom', 'Friendship', 'Person', 'Harry'),
#   ('Spell', 'Expecto Patronum', 'PerformsSpell', 'Person', 'Harry'),
#   ('Person', 'Ron', 'Possession', 'Object', 'Self Shuffling playing cards'),
#   ('Person', 'Stan', 'Addresses', 'Person', 'Cornelius Fudge'),
#   ('Person', 'Ron', 'StudentAt', 'Person', 'Professor Trelawney'),
#   ('Object', "Marauder's Map", 'Writes', 'Person', 'George'),
#   ('Person', 'Dumbledore', 'Works with', 'Person', 'McGonagall'),
#   ('Person', 'Uncle Vernon', 'No relation', 'Person', 'Harry'),
#   ('Person', 'Bill', 'Friendship', 'Person', 'Harry'),
#   ('Person', 'Lupin', 'Schoolmates with Snape', 'Person', 'Snape'),
#   ('Person', 'Sirius Black', 'After', 'Place', 'Hogwarts'),
#   ('Person', 'Harry', 'Laughs at', 'Person', 'Dursleys'),
#   ('Person', 'Tom Riddle', 'Hides with', 'Person', 'Harry'),
#   ('Person', 'Draco Malfoy', 'Competes with', 'Person', 'Harry Potter'),
#   ('Person', 'Harry', 'Asked about', 'Place', 'Hogsmeade'),
#   ('Person', 'Mr Malfoy', 'Parent of', 'Person', 'Draco Malfoy'),
#   ('Person', 'Troy', 'Drops', 'Person', 'Moran'),
#   ('Person', 'Snape', 'Sent note', 'Organisation', 'Ministry of Magic'),
#   ('Person', 'Harry', "Father's friend", 'Person', 'Wormtail'),
#   ('Person', 'Uncle Vernon', 'Speaks to', 'Person', 'Aunt Petunia'),
#   ('MagicalCreature', 'Grim', 'Haunting', 'Person', 'Harry'),
#   ('Person', 'Harry', 'ResidesIn', 'Place', 'Hogwarts'),
#   ('Person', 'Bill', 'Friendship', 'Person', 'Charlie'),
#   ('Person', 'Malfoy', 'Argues with', 'Person', 'Lee Jordan'),
#   ('Person', 'Mr Weasley', 'ColleagueOf', 'Person', 'Cuthbert Mockridge'),
#   ('Object', "Marauder's Map", 'Friendship', 'Person', 'Wormtail'),
#   ...}}

# %%
from knowledge_graph_maker import GraphMaker, Ontology, GroqClient, OpenAIClient,OllamaClient
from knowledge_graph_maker import Document

# %%
ontology = Ontology(
    labels=[
        # Entity Categories
        {"Person": "Any individual character in the Harry Potter universe, including wizards, witches, muggles, ghosts, house-elves, etc."},
        {"MagicalCreature": "Any non-human character that is a magical creature, such as house-elves, goblins, centaurs, dementors, etc."},
        {"Object": "Any magical or non-magical item without including articles like 'the'. Examples: 'Wand', 'Horcrux', 'Invisibility Cloak'."},
        {"Event": "Any significant event involving characters or groups. Example: 'Triwizard Tournament', 'Battle of Hogwarts'."},
        {"Spell": "Any magical spell or incantation. Example: 'Expelliarmus', 'Avada Kedavra', 'Lumos'."},
        {"Place": "Locations in the wizarding world, both magical and non-magical. Example: 'Hogwarts', 'Diagon Alley', 'Forbidden Forest'."},
        {"Organisation": "Groups or organizations within the universe. Example: 'Ministry of Magic', 'Dumbledore's Army', 'Death Eaters'."},
        {"Document": "Written records or texts that play a significant role. Example: 'Marauder's Map', 'The Daily Prophet'."},
        {"Potion": "Magical concoctions brewed in the wizarding world. Example: 'Polyjuice Potion', 'Felix Felicis'."},
        {"House": "Hogwarts houses to which students belong. Example: 'Gryffindor', 'Slytherin'."},
        {"QuidditchTeam": "Teams that participate in the sport of Quidditch. Example: 'Chudley Cannons', 'Holyhead Harpies'."},
        {"Miscellaneous": "Any other important concept that does not fit into other categories, such as magical laws or principles."},
        {"Artifact": "Magical items with special significance or power. Example: 'Deathly Hallows', 'Time-Turner'."},
        {"Animal": "Ordinary animals without magical abilities. Example: 'Owl', 'Cat'."},
        {"Plant": "Plants with magical properties. Example: 'Mandrake', 'Dragon Blood Vine'."},
        {"Vehicle": "Modes of transportation in the wizarding world. Example: 'Broomstick', 'Knight Bus'."},
        {"Currency": "Currencies used in the wizarding world. Example: 'Galleon', 'Sickle', 'Knut'."},
        {"Title": "Titles or designations held by characters. Example: 'Headmaster', 'Professor', 'Minister'."},
        {"Curse": "Spells with negative effects. Example: 'Imperius Curse', 'Cruciatus Curse'."},
        {"Blessing": "Spells with positive effects. Example: 'Patronus Charm'."},
        {"Ritual": "Magical rituals or ceremonies. Example: 'Horcrux creation ritual'."},
        {"Prophecy": "Foretellings or predictions about the future. Example: 'The prophecy about Harry'."},
        {"Relic": "Items of historical or cultural importance. Example: 'Godric's Relics'."},
    ],

    relationships=[
        "Relation between any pair of Entities"]
)

# %%
# ## Open AI models
# oai_model="gpt-4-turbo-ca"
# llm = OpenAIClient(model=oai_model, temperature=0.1, top_p=0.5)

# %%
model="llama3.1:8b"
llm = OllamaClient(model=model, temperature=0.1, top_p=0.5)

# %%
use_llm_doc_list = hp_text_list_all
len(use_llm_doc_list)
# Out:
# 3531

# %%
import datetime
current_time = str(datetime.datetime.now())


graph_maker = GraphMaker(ontology=ontology, llm_client=llm, verbose=False)

def generate_summary(text):
    SYS_PROMPT = (
        "Succintly summarise the text provided by the user. "
        "Respond only with the summary and no other comments"
    )
    try:
        summary = llm.generate(user_message=text, system_message=SYS_PROMPT)
    except:
        summary = ""
    finally:
        print("Summary:", summary)
        return summary


docs = map(
    lambda t: Document(text=t, metadata={"summary": generate_summary(t), 'generated_at': current_time}),
    use_llm_doc_list
)

# %%
graph = graph_maker.from_documents(
    list(docs),
    delay_s_between=0 ## delay_s_between because otherwise groq api maxes out pretty fast.
    )
print("Total number of Edges", len(graph))
# Out:
# Chapter : THE BOY WHO LIVED .  Mr and Mrs Dursley , of number four , Privet Drive , were proud to say that they were perfectly normal , thank you very much .  They were the last people you’d expect to be involved in anything strange or mysterious , because they just didn’t hold with such nonsense .  Mr Dursley was the director of a firm called Grunnings , which made drills .  He was a big , beefy man with hardly any neck , although he did have a very large mustache .  Mrs Dursley was thin and blonde and had nearly twice the usual amount of neck , which came in very useful as she spent so much of her time craning over garden fences , spying on the neighbors .  The Dursley s had a small son called Dudley and in their opinion there was no finer boy anywhere .  The Dursleys had everything they wanted , but they also had a secret , and their greatest fear was that somebody would discover it .  They didn’t think they could bear it if anyone found out about the Potters .  Mrs Potter was Mrs Dursley’s sister , but they hadn’t met for several years in fact , Mrs Dursley pretended she didn’t have a sister , because her sister and her good for nothing husband were as unDursleyish as it was possible to be .  The Dursleys shuddered to think what the neighbors would say if the Potters arrived in the street .  The Dursleys knew that the Potters had a small son , too , but they had never even seen him .  This boy was another good reason for keeping the Potters away they didn’t want Dudley mixing with a child like that .  When Mr and Mrs Dursley woke up on the dull , gray Tuesday our story starts , there was nothing about the cloudy sky outside to suggest that strange and mysterious things would soon be happening all over the country .  Mr Dursley hummed as he picked out his most boring tie for work , and Mrs Dursley gossiped away happily as she wrestled a screaming Dudley into his high chair .  None of them noticed a large , tawny owl flutter past the window .

# %%
import pickle
# 将对象保存到文件中
with open('./data/graph_object_all.pkl', 'wb') as file:
    pickle.dump(graph, file)
